# %% [markdown]
# ## Curve-fitting in Venture

# %%
from venture.venturemagics.ip_parallel import *
#from venture.venturemagics.reg_demo_utils import *
r=make_puma_church_prime_ripl()

# %%
# %%venture r
# [clear]
# [assume w0 (normal 0 3) ]
# [assume w1 (normal 0 1) ]
# [assume w2 (normal 0 .3) ]
# [assume x_d (lambda () (normal 0 5))]
# [assume noise (gamma 2 1) ]
# [assume f (lambda (x) (+ w0 (* w1 x) (* w2 (* x x)) ) ) ]
# [assume y_x (lambda (x) (normal (f x) noise) ) ]
# [assume model_name (quote simple_quadratic)]

# %%
# at any time, display all observes or assumes
assumes = display_directives(r,'assume')
# Out:
# [assume w0 (normal 0.0 3.0)]
# [assume w1 (normal 0.0 1.0)]
# [assume w2 (normal 0.0 0.3)]
# [assume x_d (lambda () (normal 0.0 5.0))]
# [assume noise (gamma 2.0 1.0)]
# [assume f (lambda (x) (add w0 (mul w1 x) (mul w2 (mul x x))))]
# [assume y_x (lambda (x) (normal (f x) noise))]
# [assume model_name (quote simple_quadratic)]

# %%
xs=list(np.random.normal(3,.7,3)) + list(np.random.normal(-1,1.4,8)) # generate x values
f = lambda x:-2*x
y_x = lambda x: np.random.normal(f(x),.6)
ys = [y_x(x) for x in xs]   # compute y values from x,f and Normal noise                                 
fig,ax = plt.subplots(figsize=(3,3))
ax.scatter(xs,ys)
ax.set_xlim(-6,6); ax.set_ylim(-8,8)

data = zip(xs,ys)
data0,data1 = data[:6],data[6:]   # split the data set in two

for i,(x,y) in enumerate(data0):
    r.observe('(x_d)', '%f' % x ) 
    r.observe('(y_x %f)' % x , '%f' % y )

# %%
plot_conditional?

# %%
# Plot prior conditional
out=plot_conditional(r,data=data0,x_range=(-8,8),number_xs=20,number_reps=20)

# %%
# Plot posterior conditional after inference
r.infer(300)
out=plot_conditional(r,data=data0,x_range=(-8,8),number_xs=20,number_reps=20)

# %%
# how to make this kind of plot?

# left plot: either extract params, or sample evaluations of f
def my_plot_conditional(ripl,x_range=(-8,8),number_xs=30):
    xr = np.linspace(x_range[0],x_range[1],number_xs)
    f_xr = np.array([ripl.predict('(f %f)' %x,label='f%i'%i) for i,x in enumerate(xr) ])
    [ripl.forget('f%i'%i) for i,x in enumerate(xr) ]

    y_xr = [ripl.predict('(y_x %f)' %x,label='y%i'%i) for i,x in enumerate(xr) ]
    [ripl.forget('y%i'%i) for i,x in enumerate(xr) ]
    
    fig,ax = plt.subplots(1,2,figsize=(4,2.5))
    ax[0].plot(xr,f_xr) ## ax[0].plot(xr,f_l,xr,f_u)
    ax[1].scatter(xr,y_xr) ##ax[1].plot(xr,y_mean,xr,y_l,xr,y_u)
    return xr,f_xr

out = my_plot_conditional(r,(-10,8),20)

# %%
print 'f(x) = %.2f + %.2fx + %.2fx^2' % (r.sample('w0'),r.sample('w1'),r.sample('w2'))
print 'y = N(f(x),%.2f)' % r.sample('noise')
# Out:
# f(x) = 4.98 + -1.65x + -0.08x^2
# y = N(f(x),1.53)

# %%
# With single ripl, we don't get a good measure of posterior uncertainty after seeing just 5 points
cli=Client()
#%px from venture.venturemagics.reg_demo_utils import *

v=MRipl(10)
v.execute_program(simple_quadratic_model)
observe_xy(v,data0)
# Out:
# New list *mripls* created on remote engines.
# MRipl has 10 ripls and 5 ripl(s) per engine
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7dd172b1aff9> in <module>()
#       4
#       5 v=MRipl(10)
# ----> 6 v.execute_program(simple_quadratic_model)
#       7 observe_xy(v,data0)
#
# NameError: name 'simple_quadratic_model' is not defined

# %%
# illustrate mapping functions across ripls (limiting to only 2 per engine)
def sample_params(r):
    return (r.sample('w0'),r.sample('w1'),r.sample('w2')), r.sample('noise') 

outs = v.map_proc(2,sample_params)
for w,noise in outs:
    print 'f(x) = %.2f + %.2fx + %.2fx^2' % w, '    y = N(f(x),%.2f)' % noise
    print '-----'
# Out:
# f(x) = 0.40 + -0.09x + 0.50x^2     y = N(f(x),0.56)
# -----
# f(x) = 0.30 + -0.56x + -0.27x^2     y = N(f(x),4.06)
# -----

# %%
# illustrate mapping with plotting function from above
outs = mr_map_proc(v,2,my_plot_conditional)

# %%
# %px from venture.venturemagics.reg_demo_utils import *

# %%
out=v.map_proc(4,plot_conditional,data=data0,x_range=(-8,8),number_xs=20,number_reps=10)
# Out:
# [0:execute]:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)<ipython-input-1-d6d0b3d365e4> in <module>()
# ----> 1 apply_out=[proc(r,*p_args,**p_kwargs) for i,r in enumerate(mripls[0]["puma"]) if i<2]
# /usr/local/lib/python2.7/dist-packages/venture/venturemagics/ip_parallel.py in plot_conditional(ripl, data, x_range, number_xs, number_reps, return_fig, figsize, plot)
#    1245
#    1246     # sample f on xr and add noise (if noise is a float)
# -> 1247     f_xr = [ripl.sample('(f %f)' % x) for x in xr]
#    1248     if "'symbol': 'noise'" in str(ripl.list_directives()):
#    1249         noise=ripl.sample('noise')
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in sample(self, expression, type)
#     463     def sample(self, expression, type=False):
#     464         i = {'instruction':'sample', 'expression':expression}
# --> 465         value = self.execute_instruction(i)['value']
#     466         return value if type else _strip_types(value)
#     467
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in execute_instruction(self, instruction, params)
#      74             stringable_instruction = parsed_instruction # Will be unparsed on use
#      75         try: # execute instruction, and handle possible exception
# ---> 76             ret_value = self.sivm.execute_instruction(parsed_instruction)
#      77         except VentureException as e:
#      78             import sys
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in execute_instruction(self, instruction)
#      60             if instruction_type in self._extra_instructions:
#      61                 f = getattr(self,'_do_'+instruction_type)
# ---> 62                 return f(instruction)
#      63             response = self._call_core_sivm_instruction(instruction)
#      64             return response
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in _do_sample(self, instruction)
#     314                 "expression" : exp,
#     315                 }
# --> 316         o1 = self._call_core_sivm_instruction(inst1)
#     317         inst2 = {
#     318                 "instruction" : "forget",
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in _call_core_sivm_instruction(self, instruction)
#     122             desugared_src_location['expression_index'] = new_index
#     123         try:
# --> 124             response = self.core_sivm.execute_instruction(desugared_instruction)
#     125         except VentureException as e:
#     126             if e.exception == "evaluation":
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in execute_instruction(self, instruction)
#      42         utils.validate_instruction(instruction,self._implemented_instructions)
#      43         f = getattr(self,'_do_'+instruction['instruction'])
# ---> 44         return f(instruction)
#      45
#      46     ###############################
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in _do_predict(self, instruction)
#      87         exp = utils.validate_arg(instruction,'expression',
#      88                 utils.validate_expression,modifier=_modify_expression, wrap_exception=False)
# ---> 89         did, val = self.engine.predict(exp)
#      90         return {"directive_id":did, "value":val}
#      91
# /usr/local/lib/python2.7/dist-packages/venture/engine/engine.pyc in predict(self, datum)
#      64     baseAddr = self.nextBaseAddr()
#      65     for trace in self.traces:
# ---> 66       trace.eval(baseAddr,self.desugarLambda(datum))
#      67
#      68     self.directives[self.directiveCounter] = ["predict",datum]
# RuntimeError: Cannot find symbol 'f'
#
# [1:execute]:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)<ipython-input-1-d6d0b3d365e4> in <module>()
# ----> 1 apply_out=[proc(r,*p_args,**p_kwargs) for i,r in enumerate(mripls[0]["puma"]) if i<2]
# /usr/local/lib/python2.7/dist-packages/venture/venturemagics/ip_parallel.py in plot_conditional(ripl, data, x_range, number_xs, number_reps, return_fig, figsize, plot)
#    1245
#    1246     # sample f on xr and add noise (if noise is a float)
# -> 1247     f_xr = [ripl.sample('(f %f)' % x) for x in xr]
#    1248     if "'symbol': 'noise'" in str(ripl.list_directives()):
#    1249         noise=ripl.sample('noise')
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in sample(self, expression, type)
#     463     def sample(self, expression, type=False):
#     464         i = {'instruction':'sample', 'expression':expression}
# --> 465         value = self.execute_instruction(i)['value']
#     466         return value if type else _strip_types(value)
#     467
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in execute_instruction(self, instruction, params)
#      74             stringable_instruction = parsed_instruction # Will be unparsed on use
#      75         try: # execute instruction, and handle possible exception
# ---> 76             ret_value = self.sivm.execute_instruction(parsed_instruction)
#      77         except VentureException as e:
#      78             import sys
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in execute_instruction(self, instruction)
#      60             if instruction_type in self._extra_instructions:
#      61                 f = getattr(self,'_do_'+instruction_type)
# ---> 62                 return f(instruction)
#      63             response = self._call_core_sivm_instruction(instruction)
#      64             return response
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in _do_sample(self, instruction)
#     314                 "expression" : exp,
#     315                 }
# --> 316         o1 = self._call_core_sivm_instruction(inst1)
#     317         inst2 = {
#     318                 "instruction" : "forget",
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in _call_core_sivm_instruction(self, instruction)
#     122             desugared_src_location['expression_index'] = new_index
#     123         try:
# --> 124             response = self.core_sivm.execute_instruction(desugared_instruction)
#     125         except VentureException as e:
#     126             if e.exception == "evaluation":
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in execute_instruction(self, instruction)
#      42         utils.validate_instruction(instruction,self._implemented_instructions)
#      43         f = getattr(self,'_do_'+instruction['instruction'])
# ---> 44         return f(instruction)
#      45
#      46     ###############################
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in _do_predict(self, instruction)
#      87         exp = utils.validate_arg(instruction,'expression',
#      88                 utils.validate_expression,modifier=_modify_expression, wrap_exception=False)
# ---> 89         did, val = self.engine.predict(exp)
#      90         return {"directive_id":did, "value":val}
#      91
# /usr/local/lib/python2.7/dist-packages/venture/engine/engine.pyc in predict(self, datum)
#      64     baseAddr = self.nextBaseAddr()
#      65     for trace in self.traces:
# ---> 66       trace.eval(baseAddr,self.desugarLambda(datum))
#      67
#      68     self.directives[self.directiveCounter] = ["predict",datum]
# RuntimeError: Cannot find symbol 'f'

# %%
outs?

# %%
# with mripls, it's easy to plot an approximation of the predictive distribution
# on y given X=x. we just need to sample y given X=x multiple times for each ripl
# and combine samples. 
out=predictive(v,data=data0,x_range=(-8,8),number_xs=40,number_reps=20)

# note that because the prior on the quadratic parameters are normals 
# symmetric about 0, our predictive distribution is symmetric

# %%
# we can now look at sample curves from our posterior:
# curves are close to the points, but they generalize
# differently
v.infer(1000)
out=v.map_proc(4, plot_conditional,data=data,x_range=(-6,6),number_xs=10,number_reps=10)

# %%
# information from all curves in our mripl
# is combined in the posterior_conditional:
# we see that our uncertainy increased 
# substantially as we move away from our data
out = predictive(v,data=data,x_range=(-6,6),number_xs=20,number_reps=20)

# %%
print simple_fourier_model

# %%
vf = MRipl(10)
vf.execute_program(simple_fourier_model)
observe_xy(vf,data=data)
vf.infer(1000)
out = vf.map_proc(4, plot_conditional, data=data, x_range=(-5,5),number_xs=20,number_reps=10)

# %%
vs = [v,vf]
[display_logscores(r) for r in vs]

# %%
# simple example of model selection. we now have prior on the distribution
# on x and we have a model that is a mixture of fourier and quadratic
print x_model_t + quad_fourier_model

# %%
v = MRipl(10)
v.execute_program(x_model_t + quad_fourier_model)
observe_xy(v,data=data)
v.infer(500)
out=v.map_proc(4, plot_conditional,data=data,x_range=(-5,5),number_xs=20, number_reps=10)

# %%
out=predictive(v,data=data,x_range=(-6,6),number_xs=20,number_reps=20)
