# %% [markdown]
# ## Venture Analytics Quickstart

# %%
from venture.unit import *
from venture.venturemagics.ip_parallel import *;
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/__init__.py:923: UserWarning:  This call to matplotlib.use() has no effect
# because the the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   if warn: warnings.warn(_use_error_msg)

# %% [markdown]
# ### Doing Inference in a Ripl vs. Analytics

# %%
# load ripl with model and observes
def loadCoin(v):
    assumes=[('p','(beta 1.0 1.0)')] 
    observes=[('(flip p)',True) for i in range(15)] 
    [v.assume(sym,exp) for sym,exp in assumes]
    [v.observe(exp,literal) for exp,literal in observes]
v=mk_p_ripl()    
loadCoin(v)
queryExps = ['(add (bernoulli p) (bernoulli p))']  # expression to query every sweep

# run inference
totalSamples=300
inferredPValues = []
for i in range(totalSamples):
    v.infer(5)
    inferredPValues.append(v.report(1))
fig,ax = subplots()
ax.hist(inferredPValues,alpha=.6,bins=20)
ax.set_title('Inference samples for p')

# %%
# load model to Analytics
model = Analytics(v,queryExps=queryExps)
print '\n Analytics object attributes: '
print '\n backend: ', model.backend
print '\n assumes: ', model.assumes
print '\n observes[:5]: ', model.observes[:5]
print '\n queryExps: ', model.queryExps
# Out:
#  Analytics object attributes:
#
#  backend:  puma
#
#  assumes:
#  [('p', '(beta 1.0 1.0)')]
#
#  observes[:5]:  [('(flip p)', True), ('(flip p)', True), ('(flip p)', True), ('(flip p)', True), ('(flip p)', True)]
#
#  queryExps:
#  ['(add (bernoulli p) (bernoulli p))']

# %%
## Run inference in Analytics
# we get a history.History object and the ripl resulting from inference

history,outRipl = model.runFromConditional(totalSamples,runs=1)

print ' history.data[:5]: ', history.data[:5]
print '\n Recorded series: ', history.nameToSeries.keys()
print '\n outRipl Assumes', [directive_split(d) for d in outRipl.list_directives() if d['instruction']=='assume']

print '\n v.sample("p")=%.2f and outRipl.sample("p")=%.2f'%(v.sample("p"),outRipl.sample("p"))
# Out:
#  history.data[:5]:  [('(flip p)', True), ('(flip p)', True), ('(flip p)', True), ('(flip p)', True), ('(flip p)', True)]
#
#  Recorded series:  ['logscore', 'sweep time (s)', 'sweep_iters', 'p', '(add (bernoulli p) (bernoulli p))']
#
#  outRipl Assumes [('p', '(beta 1.0 1.0)')]
#
#  v.sample("p")=0.88 and outRipl.sample("p")=0.96

# %%
# plot inference samples
analyticsPValues = history.nameToSeries['p'][0].values
fig,ax = subplots()
ax.hist(analyticsPValues,alpha=.6,bins=20)
ax.set_title('Analytics inference samples for p');

# %%
# plots
history.quickPlot('p')
history.quickPlot(queryExps[0])

# %% [markdown]
# ### Run on Synthetic Data (from Prior)

# %%
# Run model on data generated from prior
# we observe the same expressions but with synthetic values 
historyPrior,outRiplPrior = model.runConditionedFromPrior(totalSamples,runs=2)

# %%
print 'Ground Truth value of p:', historyPrior.groundTruth['p']['value']
parsedData = [(name,parseValue(value)) for name,value in historyPrior.data]
print 'Data generated from prior: '
for el in parsedData:
    print el
# Out:
# Ground Truth value of p: 0.827057053527
# Data generated from prior:
# ('(flip p)', True)
# ('(flip p)', True)
# ('(flip p)', True)
# ('(flip p)', True)
# ('(flip p)', True)
# ('(flip p)', True)
# ('(flip p)', True)
# ('(flip p)', True)
# ('(flip p)', True)
# ('(flip p)', True)
# ('(flip p)', True)
# ('(flip p)', True)
# ('(flip p)', True)
# ('(flip p)', True)
# ('(flip p)', True)

# %%
historyPrior.quickPlot('p')
historyPrior.quickHistogram('p')
historyPrior.quickHistogram('(add (bernoulli p) (bernoulli p))')

# %% [markdown]
# ### Analytics on MRipl

# %%
# load ripl with model and observes
v=MRipl(2,backend='puma',local_mode=True)
v.assume('mu','(normal 0 3)')
[v.observe('(normal (pow (- mu 2) 2) 1)','25') for _ in range(3)]
#  observe (mu-2)^2 + noise == 25
queryExps = ['(pow mu 2)']

# %%
model = Analytics(v,queryExps=queryExps)
history,outMRipl = model.runFromConditional(40,runs=30)  # parallel runs

# %%
history.quickPlot('mu')

# %%
# compare after 1 sweep vs. final sweep
compareSnapshots(history,probes=(0,-1),names=['mu',queryExps[0]]);
# Out:
# compareSampleDicts: run_from_conditional: snap 0 vs. run_from_conditional: snap -1
#
#
# ---------
# Name:  mu
# run_from_conditional: snap 0 : mean sem med N =  -1.590  0.522  -2.503  30
# run_from_conditional: snap -1 : mean sem med N =  -1.710  0.631  -2.986  30
# KS Test:    D stat  : 0.433333333333  P value : 0.00460706543275
#
# ---------
# Name:  (pow mu 2)
# run_from_conditional: snap 0 : mean sem med N =  10.437  2.058  8.061  30
# run_from_conditional: snap -1 : mean sem med N =  14.479  2.469  9.241  30
# KS Test:    D stat  : 0.466666666667  P value : 0.00174594988295

# %%
# compare at middle sweep vs. final sweep
compareSnapshots(history,names=['mu',queryExps[0]]);
# Out:
# compareSampleDicts: run_from_conditional: snap 20 vs. run_from_conditional: snap -1
#
#
# ---------
# Name:  mu
# run_from_conditional: snap 20 : mean sem med N =  -1.957  0.554  -2.957  30
# run_from_conditional: snap -1 : mean sem med N =  -1.710  0.631  -2.986  30
# KS Test:    D stat  : 0.133333333333  P value : 0.936008585104
#
# ---------
# Name:  (pow mu 2)
# run_from_conditional: snap 20 : mean sem med N =  12.720  2.210  9.241  30
# run_from_conditional: snap -1 : mean sem med N =  14.479  2.469  9.241  30
# KS Test:    D stat  : 0.166666666667  P value : 0.760046510261

# %%
model.gewekeTest(400,infer=None);
# Out:
# Geweke-style Test of Inference:
#
#
#         Compare iid (forward) samples from joint to dependent
#         samples from inference (*observes* changed to *predicts*)
#
# -------------
#
# compareSampleDicts: Forward iid vs. Inference
#
#
# ---------
# Name:  logscore
# Forward iid : mean sem med N =  -6.805  0.064  -6.455  500
# Inference : mean sem med N =  -6.461  0.053  -6.197  500
# KS Test:
#  D stat  : 0.116  P value : 0.00214775731581
#
# ---------
# Name:  observe[0] (normal (pow (sub mu 2.0) 2.0) 1.0)
# Forward iid : mean sem med N =  13.038  0.747  6.842  500
# Inference : mean sem med N =  2.883  0.092  2.793  500
# KS Test:
#  D stat  : 0.488  P value : 5.68772882975e-53
#
# ---------
# Name:  observe[1] (normal (pow (sub mu 2.0) 2.0) 1.0)
# Forward iid : mean sem med N =  13.104  0.748  6.942  500
# Inference : mean sem med N =  2.816  0.088  2.723  500
# KS Test:
#  D stat  : 0.484  P value : 4.10033969939e-52
#
# ---------
# Name:  observe[2] (normal (pow (sub mu 2.0) 2.0) 1.0)
# Forward iid : mean sem med N =  13.055  0.747  6.648  500
# Inference : mean sem med N =  2.856  0.087  2.726  500
# KS Test:
#  D stat  : 0.482  P value : 1.09423987061e-51
#
# ---------
# Name:  mu
# Forward iid : mean sem med N =  0.010  0.135  -0.076  500
# Inference : mean sem med N =  1.347  0.070  0.571  500
# KS Test:
#  D stat  : 0.452  P value : 1.66602123139e-45
#
# ---------
# Name:  (pow mu 2)
# Forward iid : mean sem med N =  9.089  0.560  4.232  500
# Inference : mean sem med N =  4.289  0.279  0.327  500
# KS Test:
#  D stat  : 0.386  P value : 2.66257531053e-33

# %%
numDatasets=5
sweeps=20
history,_ = model.testFromPrior(numDatasets,sweeps)    # test on multipl synthetic datasets from prior

# %%
history.quickPlot('mu')
