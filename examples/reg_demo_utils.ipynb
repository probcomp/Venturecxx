# %%
from venture.venturemagics.ip_parallel import *
from reg_demo_utils import *
clear_all_engines(); lite=False
# %load_ext autoreload
# %autoreload 2

# %%
# %%px
# def get_name(r_mr):
#     try:
#         r_mr.dview; mr=1
#     except:
#         mr=0
#     di_l = r_mr.list_directives()[0] if mr else r_mr.list_directives()
#     if 'model_name' in str(di_l):
#         try:
#             n = r_mr.sample('model_name')[0] if mr else r_mr.sample('model_name')
#             return n
#         except: pass
#     else:
#         return 'anon model'
#
#
# import numpy as np
# from scipy.stats import kde
#
# def heatplot(n2array,nbins=100):
#     """Input is an nx2 array, plots graph and returns xi,yi,zi for colormesh"""
#     x, y = n2array.T
#     k = kde.gaussian_kde(n2array.T)
#     xi, yi = np.mgrid[x.min():x.max():nbins*1j, y.min():y.max():nbins*1j]
#     zi = k(np.vstack([xi.flatten(), yi.flatten()]))
#     # plot ax.pcolormesh(xi, yi, zi.reshape(xi.shape))
#     return (xi, yi, zi.reshape(xi.shape))
#
# def if_lst_flatten(l):
#     if type(l[0])==list: return [el for subl in l for el in subl]
#     return l

# %%
print 'Student t distribution on x: ', x_model_t
print 'Mixture model of quadratic and sin functions:', quad_fourier_model
# Out:
# Student t distribution on x:
# [assume nu (gamma 10 1)]
# [assume x_d (lambda () (student_t nu) ) ]
# [assume x (mem (lambda (i) (x_d) ) )]
#
# Mixture model of quadratic and sin functions:
# [assume w0 (normal 0 3) ]
# [assume w1 (normal 0 3) ]
# [assume w2 (normal 0 1) ]
# [assume omega (normal 0 3) ]
# [assume theta (normal 0 3) ]
# [assume noise (gamma 2 1) ]
#
# [assume model (if (flip) 1 0) ]
# [assume quadratic (lambda (x) (+ w0 (* w1 x) (* w2 (* x x) ) ) ) ]
# [assume fourier (lambda (x) (+ w0 (* w1 (sin (+ (* omega x) theta) ) ) ) ) ]
# [assume f (if (= model 0) quadratic fourier) ]
#
# [assume y_x (lambda (x) (normal (f x) noise) ) ]
# [assume y (mem (lambda (i) (normal (f (x i) ) noise) ) )]
# [assume n (gamma 1 100)]
# [assume model_name (quote quad_fourier)]

# %%
# use mr_map to plot some functions f from the prior of quad_fourier
v=MRipl(4,lite=lite,verbose=False)
v.execute_program(x_model_t + quad_fourier_model)
out=mr_map_nomagic(v,plot_cond)
# Out:
# [output:0]
# [output:1]

# %%
# generate some data from y=x^2
xys = generate_data(7,xparams=[0,2],yparams=[0,0,1,0,0],sin_quad=False)

# %%
# Observe data and then run inference on MRipl
v=MRipl(5,lite=lite,verbose=False)
v.execute_program(x_model_t + quad_fourier_model)
no_transitions=100
observe_infer([v],xys,no_transitions,with_index=True,withn=True)

# Plot some functions f after inference
out=mr_map_nomagic(v,plot_cond,limit=2)
# Out:
# [output:0]
# [output:1]

# %%
# Estimated posterior conditional density P(y/X=x), by averaging over ripls in mripl
# (same data, same model)
v=MRipl(20,lite=lite,verbose=False)
v.execute_program(x_model_t + quad_fourier_model)
no_transitions=300
observe_infer([v],xys,no_transitions,with_index=True,withn=True)

out=plot_posterior_conditional(v,no_reps=10)
