# %% [markdown]
# # IPython Parallel (ip_parallel.py) Examples

# %%
# in a terminal window, do 'ipcluster start -n=#no_engines' (end with 'ipcluser stop'

#%run /[PATH]/Venturecxx/python/lib/venturemagics/ip_parallel.py
# %run ~/Venturecxx/python/lib/venturemagics/ip_parallel.py

# %%
# check that engines are running
# %px import os
# %px os.getpid()
cli=Client()
dview = cli[:]
dview.apply(lambda: 5+5).get()
# Out:
# Out[0:11]: 7254
# Out[1:11]: 7257
# [10, 10]

# %%
# construct an MRipl and load a model
def add_sprinkler(no_ripls=2,lite=False):
    clear_all_engines()
    v = MRipl(no_ripls,lite=lite)
    v.assume('r','(normal 0 30)',label='r')  # RAIN
    v.assume('s','(normal 0 30)',label='s') # SPRINKLER
    v.assume('w1','(normal (+ r s) 5.)',label='w1')   # WETNESS OF GRASS IS ADDITIVE IN RAIN, SPRINKLER
    v.observe('w1','50.')
    v.assume('w2','(normal (+ r s) 6.)',label='w2')
    v.observe('w2','50.')
    return v

v=add_sprinkler(no_ripls=30,lite=True)
snap1=v.snapshot(['r','s'],plot=True,scatter=False,logscore=False)
v.infer(100)
snap2=v.snapshot(['r','s'],plot=True,scatter=False); None
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-d4c21277b404> in <module>()
#      11     return v
#      12
# ---> 13 v=add_sprinkler(no_ripls=30,lite=True)
#      14 snap1=v.snapshot(['r','s'],plot=True,scatter=False,logscore=False)
#      15 v.infer(100)
#
# <ipython-input-5-d4c21277b404> in add_sprinkler(no_ripls, lite)
#       2 def add_sprinkler(no_ripls=2,lite=False):
#       3     clear_all_engines()
# ----> 4     v = MRipl(no_ripls,lite=lite)
#       5     v.assume('r','(normal 0 30)',label='r')  # RAIN
#       6     v.assume('s','(normal 0 30)',label='s') # SPRINKLER
#
# /home/owainevans/Venturecxx/python/lib/venturemagics/ip_parallel.py in __init__(self, no_ripls, lite, client, name)
#     122         self.local_ripl = make_church_prime_ripl()
#     123         if lite: self.local_ripl = make_lite_church_prime_ripl()
# --> 124         self.local_ripl.set_seed(0)   # same seed as first remote ripl
#     125         self.no_ripls = no_ripls
#     126         self.seeds = range(self.no_ripls)
#
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in set_seed(self, seed)
#     192
#     193     def set_seed(self, seed):
# --> 194         self.configure({'seed': seed})
#     195         return None
#     196
#
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in configure(self, options)
#     186         s = p.get_instruction_string('configure')
#     187         d = {'options':options}
# --> 188         return self.execute_instruction(s,d)['options']
#     189
#     190     def get_seed(self):
#
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in execute_instruction(self, instruction_string, params)
#      63         try:
#      64             # execute instruction, and handle possible exception
# ---> 65             ret_value = self.sivm.execute_instruction(parsed_instruction)
#      66         except VentureException as e:
#      67             # all exceptions raised by the Sivm get augmented with a
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in execute_instruction(self, instruction)
#      61                 f = getattr(self,'_do_'+instruction_type)
#      62                 return f(instruction)
# ---> 63             return self._call_core_sivm_instruction(instruction)
#      64
#      65     ###############################
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in _call_core_sivm_instruction(self, instruction)
#     100             desugared_src_location['expression_index'] = new_index
#     101         try:
# --> 102             response = self.core_sivm.execute_instruction(desugared_instruction)
#     103         except VentureException as e:
#     104             if e.exception == "evaluation":
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in execute_instruction(self, instruction)
#      42         utils.validate_instruction(instruction,self._implemented_instructions)
#      43         f = getattr(self,'_do_'+instruction['instruction'])
# ---> 44         return f(instruction)
#      45
#      46     ###############################
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in _do_configure(self, instruction)
#      84                 utils.validate_positive_integer,required=False)
#      85         if s != None:
# ---> 86             self.engine.set_seed(s)
#      87         if t != None:
#      88             #do something
#
# /usr/local/lib/python2.7/dist-packages/venture/cxx/engine.pyc in set_seed(self, seed)
#     164
#     165   def set_seed(self, seed):
# --> 166     self.trace.set_seed(seed)
#     167
#     168   def continuous_inference_status(self):
#
# AttributeError: 'Trace' object has no attribute 'set_seed'

# %%
# pull out a figure and modify it (FIXME: doesn't display figure inline, why not?)
fig = snap2['figs'][0]
ax = fig.axes
[a.grid() for a in ax]
[a.set_xlim(-100,100) for a in ax]
mean = np.mean(snap2['values']['r'])
[a.text(mean, a.get_ylim(), "Mean of values", fontsize=20, color="blue") for a in ax]
fig.show()

# %%
## probes, with histograms at various stages in history
v = add_sprinkler(no_ripls=20,lite=True)
no_transitions,no_probes = 50,3
probes,series = v.probes('r',no_transitions,no_probes,plot_hist=1,plot_series=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-76ce3cab87b3> in <module>()
#       1 ## probes, with histograms at various stages in history
# ----> 2 v = add_sprinkler(no_ripls=20,lite=True)
#       3 no_transitions,no_probes = 50,3
#       4 probes,series = v.probes('r',no_transitions,no_probes,plot_hist=1,plot_series=1)
#
# <ipython-input-5-d4c21277b404> in add_sprinkler(no_ripls, lite)
#       2 def add_sprinkler(no_ripls=2,lite=False):
#       3     clear_all_engines()
# ----> 4     v = MRipl(no_ripls,lite=lite)
#       5     v.assume('r','(normal 0 30)',label='r')  # RAIN
#       6     v.assume('s','(normal 0 30)',label='s') # SPRINKLER
#
# /home/owainevans/Venturecxx/python/lib/venturemagics/ip_parallel.py in __init__(self, no_ripls, lite, client, name)
#     122         self.local_ripl = make_church_prime_ripl()
#     123         if lite: self.local_ripl = make_lite_church_prime_ripl()
# --> 124         self.local_ripl.set_seed(0)   # same seed as first remote ripl
#     125         self.no_ripls = no_ripls
#     126         self.seeds = range(self.no_ripls)
#
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in set_seed(self, seed)
#     192
#     193     def set_seed(self, seed):
# --> 194         self.configure({'seed': seed})
#     195         return None
#     196
#
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in configure(self, options)
#     186         s = p.get_instruction_string('configure')
#     187         d = {'options':options}
# --> 188         return self.execute_instruction(s,d)['options']
#     189
#     190     def get_seed(self):
#
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in execute_instruction(self, instruction_string, params)
#      63         try:
#      64             # execute instruction, and handle possible exception
# ---> 65             ret_value = self.sivm.execute_instruction(parsed_instruction)
#      66         except VentureException as e:
#      67             # all exceptions raised by the Sivm get augmented with a
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in execute_instruction(self, instruction)
#      61                 f = getattr(self,'_do_'+instruction_type)
#      62                 return f(instruction)
# ---> 63             return self._call_core_sivm_instruction(instruction)
#      64
#      65     ###############################
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in _call_core_sivm_instruction(self, instruction)
#     100             desugared_src_location['expression_index'] = new_index
#     101         try:
# --> 102             response = self.core_sivm.execute_instruction(desugared_instruction)
#     103         except VentureException as e:
#     104             if e.exception == "evaluation":
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in execute_instruction(self, instruction)
#      42         utils.validate_instruction(instruction,self._implemented_instructions)
#      43         f = getattr(self,'_do_'+instruction['instruction'])
# ---> 44         return f(instruction)
#      45
#      46     ###############################
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in _do_configure(self, instruction)
#      84                 utils.validate_positive_integer,required=False)
#      85         if s != None:
# ---> 86             self.engine.set_seed(s)
#      87         if t != None:
#      88             #do something
#
# /usr/local/lib/python2.7/dist-packages/venture/cxx/engine.pyc in set_seed(self, seed)
#     164
#     165   def set_seed(self, seed):
# --> 166     self.trace.set_seed(seed)
#     167
#     168   def continuous_inference_status(self):
#
# AttributeError: 'Trace' object has no attribute 'set_seed'

# %%
# MULTI mripls: two multiripls with different models of same data

# we condition the value of rain on three noisy measurements of the grass being unusually wet (=50)
# the threshold model won't favor values beyond the threshold, while the additive model will 
# favor such values (until they get too high)

def add_thresh_sprinkler(no_ripls=2,add=True):
    'either wet grass is sum of rain and sprinkler, or a simple threshold function'
   
    v = MRipl(no_ripls)
    v.assume('r','(normal 0 15)',label='r')
    v.assume('s','(normal 0 15)',label='s')
    if add:
        v.assume('w','(lambda () (normal (+ r s) 5.) )',label='w')
    else:
        v.assume('w','(lambda () (if (> (+ r s) 20) (normal 30 5) (normal 0 5) ) ) ',label='w' )
    v.observe('(w)','50.')
    v.observe('(w)','50.')
    v.observe('(w)','50.')
    return v

clear_all_engines()

## Construct one mripl for additive model and one for threshold model, conditioning on same data
v_add=add_thresh_sprinkler(no_ripls=40,add=True)
v_thresh=add_thresh_sprinkler(no_ripls=40,add=False); None
# Out:
# ['(pid, index, seed)', (2579, 0, 0), (2579, 1, 1), (2579, 2, 2), (2579, 3, 3), (2579, 4, 4), (2579, 5, 5), (2579, 6, 6), (2579, 7, 7), (2579, 8, 8), (2579, 9, 9), (2579, 10, 10), (2579, 11, 11), (2579, 12, 12), (2579, 13, 13), (2579, 14, 14), (2579, 15, 15), (2579, 16, 16), (2579, 17, 17), (2579, 18, 18), (2579, 19, 19), (2580, 0, 20), (2580, 1, 21), (2580, 2, 22), (2580, 3, 23), (2580, 4, 24), (2580, 5, 25), (2580, 6, 26), (2580, 7, 27), (2580, 8, 28), (2580, 9, 29), (2580, 10, 30), (2580, 11, 31), (2580, 12, 32), (2580, 13, 33), (2580, 14, 34), (2580, 15, 35), (2580, 16, 36), (2580, 17, 37), (2580, 18, 38), (2580, 19, 39)]
# ['(pid, index, seed)', (2579, 0, 0), (2579, 1, 1), (2579, 2, 2), (2579, 3, 3), (2579, 4, 4), (2579, 5, 5), (2579, 6, 6), (2579, 7, 7), (2579, 8, 8), (2579, 9, 9), (2579, 10, 10), (2579, 11, 11), (2579, 12, 12), (2579, 13, 13), (2579, 14, 14), (2579, 15, 15), (2579, 16, 16), (2579, 17, 17), (2579, 18, 18), (2579, 19, 19), (2580, 0, 20), (2580, 1, 21), (2580, 2, 22), (2580, 3, 23), (2580, 4, 24), (2580, 5, 25), (2580, 6, 26), (2580, 7, 27), (2580, 8, 28), (2580, 9, 29), (2580, 10, 30), (2580, 11, 31), (2580, 12, 32), (2580, 13, 33), (2580, 14, 34), (2580, 15, 35), (2580, 16, 36), (2580, 17, 37), (2580, 18, 38), (2580, 19, 39)]

# %%
# sample from prior and posterior for both models
snap_add1 = v_add.snapshot('r',plot=True)
v_add.infer(100)
snap_add2 = v_add.snapshot('r',plot=True)

# %%
snap_thresh1 = v_thresh.snapshot('r',plot=True)
v_thresh.infer(100)
snap_thresh2 = v_thresh.snapshot('r',plot=True)
