# %% [markdown]
# ## Curve-fitting tutorial

# %%
from venture.venturemagics.ip_parallel import *
from venture.venturemagics.reg_demo_utils import *
r=make_puma_church_prime_ripl()

# %%
# %%venture r
# [clear]
# [assume w0 (normal 0 3) ]
# [assume w1 (normal 0 1) ]
# [assume w2 (normal 0 .3) ]
# [assume x_d (lambda () (normal 0 5))]
# [assume noise (gamma 2 1) ]
# [assume f (lambda (x) (+ w0 (* w1 x) (* w2 (* x x)) ) ) ]
# [assume y_x (lambda (x) (normal (f x) noise) ) ]
# [assume model_name (quote simple_quadratic)]

# %%
xs=list(np.random.normal(0,.5,3)) + list(np.random.normal(2,.7,2) ) 
ys = list( (-2 * np.array(xs)) + np.random.normal(0,.6,len(xs)))                                   
data=zip(xs,ys)

for i,(x,y) in enumerate(data):
    r.observe('(x_d)', '%f' % x ) 
    r.observe('(y_x %f)' % x , '%f' % y )

# %%
# Plot prior conditional
out=plot_conditional(r,data=data,x_range=(-3.5,4),no_xs=20,no_reps=30)

# %%
# Plot posterior conditional after inference
r.infer(1000)
out=plot_conditional(r,data=data,x_range=(-3.5,4),no_xs=20,no_reps=30)

# %%
print 'f(x) = %.2f + %.2fx + %.2fx^2' % (r.sample('w0'),r.sample('w1'),r.sample('w2'))
print 'y = N(f(x),%.2f)' % r.sample('noise')
# Out:
# f(x) = 0.12 + -1.94x + -0.07x^2
# y = N(f(x),0.50)

# %%
# With single ripl, we don't get a good measure of posterior uncertainty after seeing just 5 points
v=MRipl(10)
v.execute_program(simple_quadratic_model)
observe_xy(v,data)

# %%
# illustrate mapping functions across ripls (limiting to only 2 per engine)
def sample_params(r):
    return (r.sample('w0'),r.sample('w1'),r.sample('w2')), r.sample('noise') 

outs = mr_map_f(v,sample_params,limit=2)
for w,noise in outs['out']:
    print 'f(x) = %.2f + %.2fx + %.2fx^2' % w, '    y = N(f(x),%.2f)' % noise
    print '-----'
# Out:
# f(x) = 0.40 + -0.09x + 0.50x^2     y = N(f(x),0.56)
# -----
# f(x) = 0.92 + -0.42x + -0.06x^2     y = N(f(x),2.11)
# -----
# f(x) = 0.30 + -0.56x + -0.27x^2     y = N(f(x),4.06)
# -----
# f(x) = -3.28 + -0.12x + -0.26x^2     y = N(f(x),0.75)
# -----

# %%
# using same idea, we have a convenience function mapping
# plot_conditional across engines
out=mr_plot_conditional(v,limit=4,data=data,x_range=(-4,3.5),no_xs=10,no_reps=10)
# Out:
# [output:0]
# [output:1]

# %%
# with mripls, it's easy to plot an approximation of the predictive distribution
# on y given X=x. we just need to sample y given X=x multiple times for each ripl
# and combine samples. we have a convenience function 'posterior_conditional' which
# does that
out=posterior_conditional(v,data=data,x_range=(-3,3),no_xs=20,no_reps=20)

# note that because the prior on the quadratic parameters are normals 
# symmetric about 0, our predictive distribution is symmetric

# %%
# we can now look at sample curves from our posterior:
# curves are close to the points, but they generalize
# differently
v.infer(1000)
out=mr_plot_conditional(v,limit=4,data=data,x_range=(-6,6),no_xs=10,no_reps=10)
# Out:
# [output:0]
# [output:1]

# %%
# information from all curves in our mripl
# is combined in the posterior_conditional:
# we see that our uncertainy increased 
# substantially as we move away from our data
out=posterior_conditional(v,data=data,x_range=(-6,6),no_xs=20,no_reps=20)

# %%
print simple_fourier_model
# Out:
# [assume w0 (normal 0 3) ]
# [assume w1 (normal 0 3) ]
# [assume omega (normal 0 3) ]
# [assume theta (normal 0 3) ]
# [assume x (mem (lambda (i) (x_d) ) )]
# [assume x_d (lambda () (normal 0 5))]
# [assume noise (gamma 2 1) ]
# [assume f (lambda (x) (+ w0 (* w1 (sin (+ (* omega x) theta) ) ) ) ) ]
# [assume y_x (lambda (x) (normal (f x) noise) ) ]
# [assume y (mem (lambda (i) (y_x (x i))  ))]
# [assume n (gamma 1 1)]
# [assume model_name (quote simple_fourier)]

# %%
vf = MRipl(10)
vf.execute_program(simple_fourier_model)
observe_xy(vf,data=data)
vf.infer(1000)
out=mr_plot_conditional(vf,limit=4,data=data,x_range=(-5,5),no_xs=20,no_reps=10)
# Out:
# [output:0]
# [output:1]

# %%
vs = [v,vf]
[display_logscores(r) for r in vs]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-30ebe276e916> in <module>()
# ----> 1 vs = [v,vf]
#       2 [display_logscores(r) for r in vs]
#
# NameError: name 'v' is not defined

# %%
# simple example of model selection. we now have prior on the distribution
# on x and we have a model that is a mixture of fourier and quadratic
print x_model_t + quad_fourier_model
# Out:
# [assume nu (gamma 10 1)]
# [assume x_d (lambda () (student_t nu) ) ]
# [assume x (mem (lambda (i) (x_d) ) )]
#
# [assume w0 (normal 0 3) ]
# [assume w1 (normal 0 2.5) ]
# [assume w2 (normal 0 .3) ]
# [assume omega (normal 0 3) ]
# [assume theta (normal 0 3) ]
#
# [assume noise (gamma 2 1) ]
#
# [assume model (if (flip) 1 0) ]
# [assume quadratic (lambda (x) (+ w0 (* w1 x) (* w2 (* x x) ) ) ) ]
# [assume fourier (lambda (x) (+ w0 (* w1 (sin (+ (* omega x) theta) ) ) ) ) ]
# [assume f (if (= model 0) quadratic fourier) ]
#
# [assume y_x (lambda (x) (normal (f x) noise) ) ]
# [assume y (mem (lambda (i) (y_x (x i))  ))]
# [assume n (gamma 1 100)]
# [assume model_name (quote quad_fourier)]

# %%
v = MRipl(10)
v.execute_program(x_model_t + quad_fourier_model)
observe_xy(v,data=data)
v.infer(1000)
out=mr_plot_conditional(v,limit=4,data=data,x_range=(-5,5),no_xs=20,no_reps=10)
# Out:
# [output:0]
# [output:1]

# %%
out=posterior_conditional(v,data=data,x_range=(-6,6),no_xs=20,no_reps=20)
