# %% [markdown]
# # Comparison of sampling methods on a highly-correlated bivariate Gaussian

# %% [markdown]
# Below is a comparison of some of the inference methods available to Venture on a correlated bivariate Gaussian - a test case where simple proposals like MH often have trouble. I've chosen the number of iterations for each method so that they have about the same wall clock time.

# %%
# %matplotlib inline

# %%
from venture.shortcuts import make_lite_church_prime_ripl
from time import time
from utils import bivariate_normal_contour

# %% [markdown]
# Construct bivariate normal model. The goal here is to sample x0 conditioned on x1, then x1 conditioned on x0.

# %%
def build_model(rho):
    ripl = make_lite_church_prime_ripl()
    program = '''
    [assume rho {0}]
    [assume x0 (scope_include (quote data) 0 (uniform_continuous -4 4))]
    [assume x1 (scope_include (quote data) 1 (uniform_continuous -4 4))]
    [assume out (multivariate_normal (array x0 x1) (matrix (list (list 1 rho) (list rho 1))))]
    '''.format(rho)
    _ = ripl.execute_program(program)
    v = [{"type": "real", "value": 0}, {"type": "real", "value": 0}]
    ripl.observe("out", {"type":"list","value":v})
    ripl.force('x0', -1.0)
    ripl.force('x1', -1.0)
    return ripl

# %%
def annotate_plotf(plotf_output, elapsed, rho):
    'Make the plotf output prettier'
    fig = plotf_output.draw()[0]
    ax = fig.axes[0]
    ax.set_title('Elapsed time: {0:0.2f}s'.format(elapsed))
    bivariate_normal_contour(ax, mu = np.array([0,0]),
                           Sigma = np.array([[1, rho], [rho, 1]]),
                           colors = ['black'])
    ax.set_xlim([-3,3])
    ax.set_ylim([-3,3])
    return fig

# %%
def run_experiment(infer, niter, rho):
    r = build_model(rho)
    cycle_cmd = '(cycle ((plotf p0d1ds x0 x1) {0}) {1})'.format(infer, niter)
    start = time()
    res = r.infer(cycle_cmd)
    elapsed = time() - start
    fig = annotate_plotf(res, elapsed, rho)
    return fig

# %% [markdown]
# Single-site MH does OK sometimes, and very poorly on others. Although we see random-walk behavior, it is for a very different reason than in the perhaps more "conventional" MH with a Gaussian proposal centered on the current state. Here, we always resample from the prior, but the heavy correlation between variables precludes large moves through the state space.

# %%
fig = run_experiment('(mh (quote data) 0 1) (mh (quote data) 1 1)', 200, 0.99)
plt.show()

# %% [markdown]
# If the variables are uncorrelated, Venture MH does quite well

# %%
fig = run_experiment('(mh (quote data) 0 1) (mh (quote data) 1 1)', 200, 0.0)
plt.show()

# %% [markdown]
# Slice sampling generally seems more efficient, though it will get stuck on some runs.

# %%
fig = run_experiment('(slice (quote data) 0 1 100 1) (slice (quote data) 1 1 100 1)', 90, 0.99)
plt.show()

# %% [markdown]
# As with MH, uncorrelated is easy.

# %%
fig = run_experiment('(slice (quote data) 0 1 100 1) (slice (quote data) 1 1 100 1)', 90, 0.0)
plt.show()

# %% [markdown]
# Making a bad guess on the length scale for slice sampling, however, slows sampling down substantially - both wall time and exploration rate.

# %%
fig = run_experiment('(slice (quote data) 0 0.01 100 1) (slice (quote data) 1 0.01 100 1)', 80, 0.99)
plt.show()

# %% [markdown]
# The performance of slice sampling with "doubling" instead of "stepping out" seems roughly comparable.

# %%
fig = run_experiment('(slice_doubling (quote data) 0 1 100 1) (slice_doubling (quote data) 1 1 100 1)', 70, 0.99)
plt.show()

# %% [markdown]
# HMC seems to do pretty nicely

# %%
fig = run_experiment('(hmc (quote data) 0 0.1 10 1) (hmc (quote data) 1 0.1 10 1)', 70, 0.99)
plt.show()

# %% [markdown]
# ...as long as you get the parameters right. Changing the learning rate from 0.1 to 0.3 totally wrecks things.

# %%
fig = run_experiment('(hmc (quote data) 0 0.3 10 1) (hmc (quote data) 1 0.3 10 1)', 70, 0.99)
plt.show()

# %%
fig = run_experiment('(nesterov (quote data) 0 0.1 10 1) (nesterov (quote data) 1 0.1 10 1)', 50, 0.99)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-21-c0caf2abea72> in <module>()
# ----> 1 fig = run_experiment('(nesterov (quote data) 0 0.1 10 1) (nesterov (quote data) 1 0.1 10 1)', 50, 0.99)
#       2 plt.show()
#
# <ipython-input-9-76a9683635a7> in run_experiment(infer, niter, rho)
#       3     cycle_cmd = '(cycle ((plotf p0d1ds x0 x1) {0}) {1})'.format(infer, niter)
#       4     start = time()
# ----> 5     res = r.infer(cycle_cmd)
#       6     elapsed = time() - start
#       7     fig = annotate_plotf(res, elapsed, rho)
#
# /usr/local/lib/python2.7/site-packages/venture/ripl/ripl.pyc in infer(self, params, type)
#     483
#     484     def infer(self, params=None, type=False):
# --> 485         o = self.execute_instruction({'instruction':'infer', 'expression': self.defaultInferProgram(params)})
#     486         ans = o["value"]
#     487         if type:
#
# /usr/local/lib/python2.7/site-packages/venture/ripl/ripl.pyc in execute_instruction(self, instruction, params)
#     113                 stringable_instruction = instruction
#     114                 parsed_instruction = self._ensure_parsed(instruction)
# --> 115             ret_value = self.sivm.execute_instruction(parsed_instruction)
#     116         except VentureException as e:
#     117             import sys
#
# /usr/local/lib/python2.7/site-packages/venture/sivm/venture_sivm.pyc in execute_instruction(self, instruction)
#      61                 f = getattr(self,'_do_'+instruction_type)
#      62                 return f(instruction)
# ---> 63             response = self._call_core_sivm_instruction(instruction)
#      64             return response
#      65
#
# /usr/local/lib/python2.7/site-packages/venture/sivm/venture_sivm.pyc in _call_core_sivm_instruction(self, instruction)
#     122             desugared_src_location['expression_index'] = new_index
#     123         try:
# --> 124             response = self.core_sivm.execute_instruction(desugared_instruction)
#     125         except VentureException as e:
#     126             if e.exception == "evaluation":
#
# /usr/local/lib/python2.7/site-packages/venture/sivm/core_sivm.pyc in execute_instruction(self, instruction)
#      42         utils.validate_instruction(instruction,self._implemented_instructions)
#      43         f = getattr(self,'_do_'+instruction['instruction'])
# ---> 44         return f(instruction)
#      45
#      46     ###############################
#
# /usr/local/lib/python2.7/site-packages/venture/sivm/core_sivm.pyc in _do_infer(self, instruction)
#     140         e = utils.validate_arg(instruction,'expression',
#     141                 utils.validate_expression,modifier=_modify_expression, wrap_exception=False)
# --> 142         val = self.engine.infer(e)
#     143         return {"value":val}
#     144
#
# /usr/local/lib/python2.7/site-packages/venture/engine/engine.pyc in infer(self, program)
#     222     else:
#     223       exp = self.desugarLambda(self.macroexpand_inference(program))
# --> 224       return self.infer_v1_pre_t(exp, Infer(self))
#     225
#     226   def macroexpand_inference(self, program):
#
# /usr/local/lib/python2.7/site-packages/venture/engine/engine.pyc in infer_v1_pre_t(self, program, target)
#     267       next_trace.bindPrimitiveSP(name, sp)
#     268     self.install_inference_prelude(next_trace)
# --> 269     next_trace.eval(4, [program, {"type":"blob", "value":target}])
#     270     ans = next_trace.extractValue(4)
#     271     assert isinstance(ans, dict)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/trace.pyc in eval(self, id, exp)
#     305   def eval(self,id,exp):
#     306     assert not id in self.families
# --> 307     (_,self.families[id]) = evalFamily(self,self.unboxExpression(exp),self.globalEnv,Scaffold(),False,OmegaDB(),{})
#     308
#     309   def bindInGlobalEnv(self,sym,id): self.globalEnv.addBinding(sym,self.families[id])
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
# ...
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     139 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     140   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 141   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199         weight += restore(trace,esrParent,scaffold,omegaDB,gradients)
#     200       else:
# --> 201         (w,esrParent) = evalFamily(trace,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     202         weight += w
#     203       trace.registerFamilyAt(node,esr.id,esrParent)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     119     for index, subexp in enumerate(exp):
#     120       try:
# --> 121         w, n = evalFamily(trace,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     122         weight += w
#     123         nodes.append(n)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in evalFamily(trace, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     130     (requestNode,outputNode) = trace.createApplicationNodes(nodes[0],nodes[1:],env)
#     131     try:
# --> 132       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     133     except VentureError as err:
#     134       err.stack_frame = StackFrame(exp, [], err.stack_frame)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     142   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     143   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 144   weight += applyPSP(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     145   assert isinstance(weight, numbers.Number)
#     146   return weight
#
# /usr/local/lib/python2.7/site-packages/venture/lite/regen.pyc in applyPSP(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     173   else:
#     174     # if we simulate from the prior, the weight is 0
# --> 175     newValue = psp.simulate(args) if not shouldRestore else oldValue
#     176
#     177   trace.setValueAt(node,newValue)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/psp.pyc in simulate(self, args)
#     261
#     262   def simulate(self,args):
# --> 263     return self.f_type.wrap_return(self.psp.simulate(self.f_type.unwrap_args(args)))
#     264   def gradientOfSimulate(self, args, value, direction):
#     265     return self.psp.gradientOfSimulate(self.f_type.unwrap_args(args), self.f_type.unwrap_return(value), direction)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/inference_sps.pyc in simulate(self, args)
#      18   def canAbsorb(self, _trace, _appNode, _parentNode): return False
#      19   def simulate(self, args):
# ---> 20     args.operandValues[0].primitive_infer(self.exp)
#      21     return args.operandValues[0]
#      22
#
# /usr/local/lib/python2.7/site-packages/venture/engine/inference.pyc in primitive_infer(self, exp)
#      53       return str(exp)
#      54
# ---> 55   def primitive_infer(self, exp): self.engine.primitive_infer(exp)
#      56   def resample(self, ct): self.engine.resample(ct)
#      57   def incorporate(self): pass # Since we incorporate at the beginning anyway
#
# /usr/local/lib/python2.7/site-packages/venture/engine/engine.pyc in primitive_infer(self, exp)
#     283       if hasattr(trace, "infer_exp"):
#     284         # The trace can handle the inference primitive syntax natively
# --> 285         trace.infer_exp(exp)
#     286       else:
#     287         # The trace cannot handle the inference primitive syntax
#
# /usr/local/lib/python2.7/site-packages/venture/lite/trace.pyc in infer_exp(self, exp)
#     421       elif operator == "nesterov":
#     422         (rate, steps) = exp[3:5]
# --> 423         mixMH(self, BlockScaffoldIndexer(scope, block), NesterovAcceleratedGradientAscentOperator(rate, int(steps)))
#     424       elif operator == "rejection":
#     425         mixMH(self, BlockScaffoldIndexer(scope, block), RejectionOperator())
#
# /usr/local/lib/python2.7/site-packages/venture/lite/infer/mh.pyc in mixMH(trace, indexer, operator)
#      20   # May mutate trace and possibly operator, proposedTrace is the mutated trace
#      21   # Returning the trace is necessary for the non-mutating versions
# ---> 22   proposedTrace,logAlpha = operator.propose(trace,index)
#      23   xiMix = indexer.logDensityOfIndex(proposedTrace,index)
#      24
#
# /usr/local/lib/python2.7/site-packages/venture/lite/infer/map_gradient.pyc in propose(self, trace, scaffold)
#      24
#      25     # Smashes the trace but leaves it a torus
# ---> 26     proposed_values = self.evolve(grad, currentValues, start_grad)
#      27
#      28     _xiWeight = grad.regen(proposed_values) # Mutates the trace
#
# /usr/local/lib/python2.7/site-packages/venture/lite/infer/map_gradient.pyc in evolve(self, grad, values, start_grad)
#      56       new_ys = [x + dx*self.epsilon for (x,dx) in zip(xs, dxs)]
#      57       new_xs = [old_y * gam + new_y * (1-gam) for (old_y, new_y) in zip(ys, new_ys)]
# ---> 58       (xs, ys, dxs, lam) = (new_ys, new_ys, grad(new_xs), self.step_lam(lam))
#      59     return xs
#      60   def name(self): return "gradient ascent with Nesterov acceleration"
#
# /usr/local/lib/python2.7/site-packages/venture/lite/infer/hmc.pyc in __call__(self, values)
#      44     new_scaffold = constructScaffold(self.trace, [set(self.pnodes)])
#      45     registerDeterministicLKernels(self.trace, new_scaffold, self.pnodes, values)
# ---> 46     (_, rhoDB) = detachAndExtract(self.trace, new_scaffold, True)
#      47     self.scaffold = new_scaffold
#      48     return [rhoDB.getPartial(pnode) for pnode in self.pnodes]
#
# /usr/local/lib/python2.7/site-packages/venture/lite/detach.pyc in detachAndExtract(trace, scaffold, compute_gradient)
#       9   assertTrace(trace, scaffold)
#      10   assert len(scaffold.border) == 1
# ---> 11   ans = detachAndExtractAtBorder(trace, scaffold.border[0], scaffold, compute_gradient=compute_gradient)
#      12   assertTorus(scaffold)
#      13   return ans
#
# /usr/local/lib/python2.7/site-packages/venture/lite/detach.pyc in detachAndExtractAtBorder(trace, border, scaffold, compute_gradient)
#      24   for node in reversed(border):
#      25     if scaffold.isAbsorbing(node):
# ---> 26       weight += detach(trace, node, scaffold, omegaDB, compute_gradient)
#      27     else:
#      28       if node.isObservation: weight += unconstrain(trace,trace.getConstrainableNode(node))
#
# /usr/local/lib/python2.7/site-packages/venture/lite/detach.pyc in detach(trace, node, scaffold, omegaDB, compute_gradient)
#      46   if compute_gradient:
#      47     # Ignore the partial derivative of the value because the value is fixed
# ---> 48     (_, grad) = psp.gradientOfLogDensity(gvalue, args)
#      49     omegaDB.addPartials(args.operandNodes + trace.esrParentsAt(node), grad)
#      50   weight += extractParents(trace, node, scaffold, omegaDB, compute_gradient)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/psp.pyc in gradientOfLogDensity(self, value, args)
#     268   def gradientOfLogDensity(self, value, args):
#     269     (dvalue, dargs) = self.psp.gradientOfLogDensity(self.f_type.unwrap_return(value), self.f_type.unwrap_args(args))
# --> 270     return (self.f_type.gradient_type().wrap_return(dvalue), self.f_type.gradient_type().wrap_arg_list(dargs))
#     271   def logDensityBound(self, value, args):
#     272     return self.psp.logDensityBound(self.f_type.unwrap_return(value), self.f_type.unwrap_args(args))
#
# /usr/local/lib/python2.7/site-packages/venture/lite/sp.pyc in wrap_arg_list(self, lst)
#     106       assert len(lst) <= len(self.args_types)
#     107       # v could be None when computing log density bounds for a torus
# --> 108       return [self.args_types[i].asVentureValue(v) for (i,v) in enumerate(lst)]
#     109     else:
#     110       return [self.args_types[0].asVentureValue(v) for v in lst]
#
# /usr/local/lib/python2.7/site-packages/venture/lite/value.pyc in asVentureValue(self, thing)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/value.pyc in __init__(self, matrix)
#     791   def __init__(self, matrix):
#     792     self.matrix = np.asarray(matrix)
# --> 793     assert matrixIsSymmetric(self.matrix)
#     794   def __repr__(self):
#     795     return "VentureSymmetricMatrix(%s)" % self.matrix
#
# AssertionError:
