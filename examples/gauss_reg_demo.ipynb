# %% [markdown]
# # Venture Tutorial Part 2

# %% [markdown]
# ----

# %%
from venture.venturemagics.ip_parallel import MRipl,display_directives,mk_p_ripl
make_ripl = mk_p_ripl

# %% [markdown]
# -----

# %% [markdown]
# ## Inferring the Mean and Variance of a Gaussian Distribution

# %% [markdown]
# ### 1. Specifying and plotting the prior

# %% [markdown]
# These are the heights of a group of a 18-year-old men. We'd like to make an inference about the population based on this data.

# %%
male18=[179,195.1,183.7,178.7,171.5,181.8,172.5,
        174.6,190.4,173.8,172.6,185.2,178.4,
        177.6,183.5,178.1,177,172.9,188.4,169.4,
        180.2,189,182.4,185.8,180.7,178.7]
data=male18
fig,ax=plt.subplots(figsize=(4,2))
ax.hist(data, alpha=.6, color='orange')
ax.set_title('Histogram of Heights for 18 year-old Males');

# %% [markdown]
# We model the population distribution as a Gaussian with unknown mean `mu` and standard deviation `sigma`. We place broad priors on each of the variables. We then define `x` as a stochastic procedure that samples a height i.i.d. given `mu` and `sigma`.

# %%
v=MRipl(80)
# Out:
# MRipl has 80 ripls and 40 ripl(s) per engine

# %%
# %%venture v
# [assume mu (normal 0 60) ]
# [assume sigma (gamma 2 .2) ]
# [assume x (lambda () (normal mu sigma) ) ]
# Out:
# Ripl 0 of 80:  [8.035116487120552, 11.607440026103758, 'unknown']
# Ripl 1 of 80:  [18.383970739828563, 8.336089577294677, 'unknown']
# Ripl 2 of 80:  [-78.18634280929683, 8.730709432215562, 'unknown']
# Ripl 3 of 80:  [-45.46512864514391, 29.04919461163236, 'unknown']
# Ripl 4 of 80:  [-76.36545111627048, 2.3106878954474257, 'unknown']
# ...

# %% [markdown]
# We can visualize our prior on `mu` and `sigma`, as well as their covariance, via the 'scatter' option for `snapshot`.

# %%
v.snapshot(('mu','sigma'), plot=True, scatter=True);

# %% [markdown]
# Each pair (`mu`, `sigma`) produces a distinct Gaussian population distribution generated from sampling `x`. Using the MRipl method `sample_populations`, we can plot some of these populations (sampled from the model prior).
#
# The form is:
# ```python
# <mripl>.sample_populations(<stochastic_expression>, <number_populations>, <population_size>)
# ```

# %%
out=v.sample_populations('(x)', 5, 100)

# %%
out=v.sample_populations('(x)', 4, 100)

# %%
squared_x = v.sample_populations('(pow (x) 2)', 4, 100)

# %% [markdown]
# If we sample a population from each RIPL in the MRipl and collapse all individuals into one big population, we get an approximation of the marginal prior on heights.

# %%
outs=v.snapshot('(x)',plot=True,repeat=60)

# %% [markdown]
# ----

# %% [markdown]
# ### 2. Conditioning the model on data

# %% [markdown]
# We condition the model using the `observe` directive. As with the 'Tricky Coin' example, we can either condition _incrementally_, interleaving `observe` and `infer` directives, or we can condition on all the data at once. Here we exhibit incremental conditioning.

# %%
prior_mu = v.snapshot('mu')

v.observe('(x)', data[0] )
print 'Observed data: ', data[:1]

v.infer(500)
posterior1_mu=v.snapshot('mu')
fig = v.compare_snapshots( (prior_mu,posterior1_mu) )
# Out:
# Observed data:  [179]

# %%
v.observe('(x)',data[1] )
print 'Observed data: ', data[:2]

v.infer(500)
posterior2_mu=v.snapshot('mu')

# NOTE: we are comparing the posterior given two data-points to the original prior:
# i.e. the prior before conditioning on any data
fig = v.compare_snapshots( (prior_mu,posterior2_mu) )
# Out:
# Observed data:  [179, 195.1]

# %%
v.observe('(x)', data[2] )
v.observe('(x)', data[3] )
print 'Observed data: ', data[:4]

v.infer(500)
posterior3_mu=v.snapshot('mu')
fig = v.compare_snapshots( (prior_mu, posterior1_mu, posterior2_mu, posterior3_mu) )
# Out:
# Observed data:  [179, 195.1, 183.7, 178.7]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-8c43fb24d588> in <module>()
#       5 v.infer(500)
#       6 posterior3_mu=v.snapshot('mu')
# ----> 7 fig = v.compare_snapshots(prior_mu, posterior1_mu, posterior2_mu, posterior3_mu)
#
# TypeError: compare_snapshots() takes exactly 2 arguments (5 given)

# %% [markdown]
# Having conditioned on 5 datapoints from the Male heights dataset, we call `sample_populations` on the MRipl. These are populations with height distributions that are plausible given the data seen so far. Calling `snapshot` with the `repeat` option gives us an approximate posterior marginal on height.

# %%
populations=v.sample_populations('(x)', 4, 90);

# %%
posterior_marginal_x = v.snapshot('(x)', plot=True, repeat=60)

# %% [markdown]
# ----

# %% [markdown]
# ## Making inference robust to outliers

# %%
from venture.venturemagics.ip_parallel import *
male18=[179,195.1,183.7,178.7,171.5,181.8,172.5,
        174.6,190.4,173.8,172.6,185.2,178.4,
        177.6,183.5,178.1,177,172.9,188.4,169.4,
        180.2,189,182.4,185.8,180.7,178.7]
data=male18
v=MRipl(80)
# Out:
# MRipl has 80 ripls and 40 ripl(s) per engine

# %%
# %%venture v
# [assume mu (normal 0 60) ]
# [assume sigma (gamma 2 .2) ]
# [assume x (lambda () (normal mu sigma))]
# Out:
# Ripl 0 of 80:  [8.035116487120552, 11.607440026103758, 'unknown']
# Ripl 1 of 80:  [18.383970739828563, 8.336089577294677, 'unknown']
# Ripl 2 of 80:  [-78.18634280929683, 8.730709432215562, 'unknown']
# Ripl 3 of 80:  [-45.46512864514391, 29.04919461163236, 'unknown']
# Ripl 4 of 80:  [-76.36545111627048, 2.3106878954474257, 'unknown']
# ...

# %%
[v.observe('(x)',datum) for datum in data[:4]]
v.infer(600)
posterior_before_outlier=v.snapshot('mu',plot=True);

# %%
v.observe('(x)',325)
v.infer(600)
posterior_after_outlier=v.snapshot('mu')
shift_due_outlier = v.compare_snapshots( (posterior_before_outlier, posterior_after_outlier) )
# Out:
# {'figs': <matplotlib.figure.Figure at 0xa97bfec>,
#  'ripls_info': [(3556, 0, '<venture.ripl.ripl.Ripl instance at 0x13b9f04c>'),
#   (3556, 1, '<venture.ripl.ripl.Ripl instance at 0x13b9f10c>'),
#   (3556, 2, '<venture.ripl.ripl.Ripl instance at 0x13b9f1cc>'),
#   (3556, 3, '<venture.ripl.ripl.Ripl instance at 0x13b9f28c>'),
#   (3556, 4, '<venture.ripl.ripl.Ripl instance at 0x13b9f34c>'),
#   (3556, 5, '<venture.ripl.ripl.Ripl instance at 0x13b9f40c>'),
#   (3556, 6, '<venture.ripl.ripl.Ripl instance at 0x13b9f4cc>'),
#   (3556, 7, '<venture.ripl.ripl.Ripl instance at 0x13b9f58c>'),
#   (3556, 8, '<venture.ripl.ripl.Ripl instance at 0x13b9f64c>'),
#   (3556, 9, '<venture.ripl.ripl.Ripl instance at 0x13b9f70c>'),
#   (3556, 10, '<venture.ripl.ripl.Ripl instance at 0x13b9f7cc>'),
#   (3556, 11, '<venture.ripl.ripl.Ripl instance at 0x13b9f88c>'),
#   (3556, 12, '<venture.ripl.ripl.Ripl instance at 0x13b9f94c>'),
#   (3556, 13, '<venture.ripl.ripl.Ripl instance at 0x13b9fa0c>'),
#   (3556, 14, '<venture.ripl.ripl.Ripl instance at 0x13b9facc>'),
#   (3556, 15, '<venture.ripl.ripl.Ripl instance at 0x13b9fb8c>'),
#   (3556, 16, '<venture.ripl.ripl.Ripl instance at 0x13b9fc4c>'),
#   (3556, 17, '<venture.ripl.ripl.Ripl instance at 0x13b9fd0c>'),
#   (3556, 18, '<venture.ripl.ripl.Ripl instance at 0x13b9fdcc>'),
#   (3556, 19, '<venture.ripl.ripl.Ripl instance at 0x13b9fe8c>'),
#   (3556, 20, '<venture.ripl.ripl.Ripl instance at 0x13b9ff4c>'),
#   (3556, 21, '<venture.ripl.ripl.Ripl instance at 0x13c4f02c>'),
#   (3556, 22, '<venture.ripl.ripl.Ripl instance at 0x13c4f0ec>'),
#   (3556, 23, '<venture.ripl.ripl.Ripl instance at 0x13c4f1ac>'),
#   (3556, 24, '<venture.ripl.ripl.Ripl instance at 0x13c4f26c>'),
#   (3556, 25, '<venture.ripl.ripl.Ripl instance at 0x13c4f32c>'),
#   (3556, 26, '<venture.ripl.ripl.Ripl instance at 0x13c4f3ec>'),
#   (3556, 27, '<venture.ripl.ripl.Ripl instance at 0x13c4f4ac>'),
#   (3556, 28, '<venture.ripl.ripl.Ripl instance at 0x13c4f56c>'),
#   (3556, 29, '<venture.ripl.ripl.Ripl instance at 0x13c4f62c>'),
#   (3556, 30, '<venture.ripl.ripl.Ripl instance at 0x13c4f6ec>'),
#   (3556, 31, '<venture.ripl.ripl.Ripl instance at 0x13c4f7ac>'),
#   (3556, 32, '<venture.ripl.ripl.Ripl instance at 0x13c4f86c>'),
#   (3556, 33, '<venture.ripl.ripl.Ripl instance at 0x13c4f92c>'),
#   (3556, 34, '<venture.ripl.ripl.Ripl instance at 0x13c4f9ec>'),
#   (3556, 35, '<venture.ripl.ripl.Ripl instance at 0x13c4faac>'),
#   (3556, 36, '<venture.ripl.ripl.Ripl instance at 0x13c4fb6c>'),
#   (3556, 37, '<venture.ripl.ripl.Ripl instance at 0x13c4fc2c>'),
#   (3556, 38, '<venture.ripl.ripl.Ripl instance at 0x13c4fcec>'),
#   (3556, 39, '<venture.ripl.ripl.Ripl instance at 0x13c4fdac>'),
#   (3557, 40, '<venture.ripl.ripl.Ripl instance at 0x1419a04c>'),
#   (3557, 41, '<venture.ripl.ripl.Ripl instance at 0x1419a10c>'),
#   (3557, 42, '<venture.ripl.ripl.Ripl instance at 0x1419a1cc>'),
#   (3557, 43, '<venture.ripl.ripl.Ripl instance at 0x1419a28c>'),
#   (3557, 44, '<venture.ripl.ripl.Ripl instance at 0x1419a34c>'),
#   (3557, 45, '<venture.ripl.ripl.Ripl instance at 0x1419a40c>'),
#   (3557, 46, '<venture.ripl.ripl.Ripl instance at 0x1419a4cc>'),
#   (3557, 47, '<venture.ripl.ripl.Ripl instance at 0x1419a58c>'),
#   (3557, 48, '<venture.ripl.ripl.Ripl instance at 0x1419a64c>'),
#   (3557, 49, '<venture.ripl.ripl.Ripl instance at 0x1419a70c>'),
#   (3557, 50, '<venture.ripl.ripl.Ripl instance at 0x1419a7cc>'),
#   (3557, 51, '<venture.ripl.ripl.Ripl instance at 0x1419a88c>'),
#   (3557, 52, '<venture.ripl.ripl.Ripl instance at 0x1419a94c>'),
#   (3557, 53, '<venture.ripl.ripl.Ripl instance at 0x1419aa0c>'),
#   (3557, 54, '<venture.ripl.ripl.Ripl instance at 0x1419aacc>'),
#   (3557, 55, '<venture.ripl.ripl.Ripl instance at 0x1419ab8c>'),
#   (3557, 56, '<venture.ripl.ripl.Ripl instance at 0x1419ac4c>'),
#   (3557, 57, '<venture.ripl.ripl.Ripl instance at 0x1419ad0c>'),
#   (3557, 58, '<venture.ripl.ripl.Ripl instance at 0x1419adcc>'),
#   (3557, 59, '<venture.ripl.ripl.Ripl instance at 0x1419ae8c>'),
#   (3557, 60, '<venture.ripl.ripl.Ripl instance at 0x1419af4c>'),
#   (3557, 61, '<venture.ripl.ripl.Ripl instance at 0x1426002c>'),
#   (3557, 62, '<venture.ripl.ripl.Ripl instance at 0x142600ec>'),
#   (3557, 63, '<venture.ripl.ripl.Ripl instance at 0x142601ac>'),
#   (3557, 64, '<venture.ripl.ripl.Ripl instance at 0x1426026c>'),
#   (3557, 65, '<venture.ripl.ripl.Ripl instance at 0x1426032c>'),
#   (3557, 66, '<venture.ripl.ripl.Ripl instance at 0x142603ec>'),
#   (3557, 67, '<venture.ripl.ripl.Ripl instance at 0x142604ac>'),
#   (3557, 68, '<venture.ripl.ripl.Ripl instance at 0x1426056c>'),
#   (3557, 69, '<venture.ripl.ripl.Ripl instance at 0x1426062c>'),
#   (3557, 70, '<venture.ripl.ripl.Ripl instance at 0x142606ec>'),
#   (3557, 71, '<venture.ripl.ripl.Ripl instance at 0x142607ac>'),
#   (3557, 72, '<venture.ripl.ripl.Ripl instance at 0x1426086c>'),
#   (3557, 73, '<venture.ripl.ripl.Ripl instance at 0x1426092c>'),
#   (3557, 74, '<venture.ripl.ripl.Ripl instance at 0x142609ec>'),
#   (3557, 75, '<venture.ripl.ripl.Ripl instance at 0x14260aac>'),
#   (3557, 76, '<venture.ripl.ripl.Ripl instance at 0x14260b6c>'),
#   (3557, 77, '<venture.ripl.ripl.Ripl instance at 0x14260c2c>'),
#   (3557, 78, '<venture.ripl.ripl.Ripl instance at 0x14260cec>'),
#   (3557, 79, '<venture.ripl.ripl.Ripl instance at 0x14260dac>')],
#  'total_transitions': 1200,
#  'values': {}}

# %%
v_robust = MRipl(40)
# Out:
# MRipl has 40 ripls and 20 ripl(s) per engine

# %%
# %%venture v_robust
# [assume mu (normal 0 60) ]
# [assume sigma (gamma 2 .2) ]
# [assume x (lambda () (if (flip .95) (normal mu sigma) (normal mu (* 5 sigma) ) ) ) ]
# Out:
# Ripl 0 of 40:  [8.035116487120552, 11.607440026103758, 'unknown']
# Ripl 1 of 40:  [18.383970739828563, 8.336089577294677, 'unknown']
# Ripl 2 of 40:  [-78.18634280929683, 8.730709432215562, 'unknown']
# Ripl 3 of 40:  [-45.46512864514391, 29.04919461163236, 'unknown']
# Ripl 4 of 40:  [-76.36545111627048, 2.3106878954474257, 'unknown']
# ...

# %%
[v_robust.observe('(x)',datum) for datum in data[:4]]
v_robust.infer(600)
posterior_before_outlier = v_robust.snapshot('mu')

v_robust.observe('(x)',325)

v_robust.infer(600)
posterior_after_outlier = v_robust.snapshot('mu')
out = v_robust.compare_snapshots( (posterior_before_outlier, posterior_after_outlier) )

# %%
print 'basic model mean logscore: ', np.mean(v.get_global_logscore())
print 'robust model mean logscore: ', np.mean(v_robust.get_global_logscore())
