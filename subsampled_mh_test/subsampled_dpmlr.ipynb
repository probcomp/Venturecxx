# %% [markdown]
# # Subsampled MH for DP Mixture of Logistic Regression Experts

# %%
import numpy as np
import ipdb
import time
from venture.venturemagics.ip_parallel import *
from venture.unit import Analytics
make_ripl = mk_l_ripl
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
v=make_ripl()

# %% [markdown]
# #### Synthetic Data

# %%
D = 2
N = 10
w = np.random.normal(0, np.sqrt(0.1), D + 1).tolist()
xs = np.random.normal(0, 1, [N, D])
fs = xs.dot(w[1:]) + w[0]
ys = np.random.random(N) < 1 / (1 + np.exp(-fs))
xs = xs.tolist()
ys = ys.tolist()

# %%
"""
# %%venture v
[clear]
[assume D 2]
[assume mu (zeros_array (+ D 1))]
[assume Sigma (diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (+ D 1))))]
[assume alpha (scope_include (quote scope_alpha) 0 (uniform_continuous .5 1))]
[assume crp (make_crp alpha) ]
[assume z (mem (lambda (i) (scope_include (quote scope_z) i (crp))))]
[assume w (mem (lambda (z) (scope_include (quote scope_w) z (multivariate_normal mu Sigma))))]
[assume f_x (lambda (x i) (dot_product (cat_array (array 1) x) (w (z i))))]
[assume y_x (lambda (x i) (scope_include (quote scope_y) i (bernoulli (/ 1 (+ 1 (exp (- 0 (f_x x i))))))))]
"""

# %%
# %%venture v
# [clear]
# [assume D 2]
# [assume mu (zeros_array (+ D 1))]
# [assume Sigma (diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (+ D 1))))]
# [assume alpha (scope_include (quote alpha) 0 (uniform_continuous .1 1))]
# [assume crp (make_crp alpha) ]
# [assume z (mem (lambda (i) (scope_include (quote sc_z) i (crp))))]
# [assume w (mem (lambda (z) (scope_include (quote w) z (multivariate_normal mu Sigma))))]
# [assume y_x (lambda (x i) (bernoulli (linear_logistic (w (z i)) x)))]

# %%
# %%venture v
# [clear]
# [assume D 2]
# [assume alpha (scope_include (quote alpha) 0 (uniform_continuous .1 1))]
# [assume crp (make_crp alpha) ]
# [assume z (mem (lambda (i) (scope_include (quote scope_z) i (crp))))]
# [assume w (mem (lambda (z) (scope_include (quote scope_w) z (normal 0 1))))]
# [assume y (lambda (i) (normal (w (z i)) 1))]
# [observe (scope_include (quote scope_y) 0 (y 0)) .1]
# [observe (scope_include (quote scope_y) 1 (y 1)) .2]
# [observe (scope_include (quote scope_y) 2 (y 2)) .3]

# %%
v.infer('(gibbs scope_z one 1)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-bc07c3ddbe2f> in <module>()
# ----> 1 v.infer('(gibbs scope_z one 1)')
#
# /usr/local/lib/python2.7/site-packages/venture/ripl/ripl.pyc in infer(self, params)
#     397
#     398     def infer(self, params=None):
# --> 399         self.execute_instruction({'instruction':'infer', 'params': self.parseInferParams(params)})
#     400
#     401     def clear(self):
#
# /usr/local/lib/python2.7/site-packages/venture/ripl/ripl.pyc in execute_instruction(self, instruction, params)
#      73             stringable_instruction = parsed_instruction # Will be unparsed on use
#      74         try: # execute instruction, and handle possible exception
# ---> 75             ret_value = self.sivm.execute_instruction(parsed_instruction)
#      76         except VentureException as e:
# ...

# %%
for d in v.list_directives():
    print directive_split(d)
# Out:
# ('D', '2.0')
# ('mu', '(zeros_array (add D 1.0))')
# ('Sigma', '(diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (add D 1.0))))')
# ('alpha', '(scope_include (quote alpha) 0.0 (uniform_continuous 0.1 1.0))')
# ('crp', '(make_crp alpha)')
# ('z', '(mem (lambda (i) (scope_include (quote z) i (crp))))')
# ('w', '(mem (lambda (z) (scope_include (quote w) z (multivariate_normal mu Sigma))))')
# ('y_x', '(lambda (x i) (scope_include (quote y) i (bernoulli (linear_logistic (w (z i)) x))))')

# %%
for n in xrange(N):
    v.observe('(scope_include (quote y) %d (y_x (array %s) %d))' \
              % (n, ' '.join(['%f' % x for x in xs[n]]), n), ys[n])

# %%
zs = [v.sample('(z %d)' % n) for n in xrange(N)]
print zs
# Out:
# [1, 2, 1, 2, 2, 2, 1, 1, 2, 1]

# %%
for z in range(1,max(zs)+1):
    print v.sample('(w %d)' % z)
# Out:
# [-0.14080323236464148, -0.3418607605134668, -0.3541085711022848]
# [0.5058423306127576, -0.029595351730483506, -0.015130107866587816]

# %%
xt = zip(*[xs[i] for i in range(len(xs)) if ys[i]])
plot(xt[0], xt[1], 'gx')
xt = zip(*[xs[i] for i in range(len(xs)) if not ys[i]])
plot(xt[0], xt[1], 'rx')

# %%
v.infer('(mh scope_w all 1)')
print v.sample('(w 1)')
print v.sample('(w 2)')
print v.sample('(w 3)')
# Out:
# [-0.0241133344739447, 0.80701904292074, 0.2457950954109486]
# [-0.15440527983830438, -1.2082041659046077, 0.07860094149297278]
# [-0.8974181077356115, 0.07840717545301083, 0.22535969055689012]

# %%
ipdb.runcall(v.infer, '(pgibbs z one 1)')
# Out:
# > /usr/local/lib/python2.7/site-packages/venture/ripl/ripl.py(399)infer()
#     398     def infer(self, params=None):
# --> 399         self.execute_instruction({'instruction':'infer', 'params': self.parseInferParams(params)})
#     400
# ipdb> q

# %%
v.infer('(gibbs sc_z one 1)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-6d1ac83481de> in <module>()
# ----> 1 v.infer('(gibbs sc_z one 1)')
#
# /usr/local/lib/python2.7/site-packages/venture/ripl/ripl.pyc in infer(self, params)
#     397
#     398     def infer(self, params=None):
# --> 399         self.execute_instruction({'instruction':'infer', 'params': self.parseInferParams(params)})
#     400
#     401     def clear(self):
#
# /usr/local/lib/python2.7/site-packages/venture/ripl/ripl.pyc in execute_instruction(self, instruction, params)
#      73             stringable_instruction = parsed_instruction # Will be unparsed on use
#      74         try: # execute instruction, and handle possible exception
# ---> 75             ret_value = self.sivm.execute_instruction(parsed_instruction)
#      76         except VentureException as e:
# ...

# %%
print [v.sample('(z %d)' % d) for d in range(N)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-da3f6a5cd219> in <module>()
#       1 v.infer('(pgibbs sc_z one 1 3)')
# ----> 2 print [v.sample('(z %d)' % d) for d in range(N)]
#
# /usr/local/lib/python2.7/site-packages/venture/ripl/ripl.pyc in sample(self, expression, type)
#     434     def sample(self, expression, type=False):
#     435         i = {'instruction':'sample', 'expression':expression}
# --> 436         value = self.execute_instruction(i)['value']
#     437         return value if type else _strip_types(value)
#     438
#
# /usr/local/lib/python2.7/site-packages/venture/ripl/ripl.pyc in execute_instruction(self, instruction, params)
#      73             stringable_instruction = parsed_instruction # Will be unparsed on use
#      74         try: # execute instruction, and handle possible exception
# ...

# %% [markdown]
# ### Plot the scaffold

# %%
plt.figure(figsize=(35,35))
v.infer({'kernel': 'draw_scaffold', 'scope': 'default', 'block' : 'all', 'transitions': 1})
print 'Scaffold of default'
plt.savefig('/Users/yutian/Desktop/scaffold_dpmlr_scope_default.pdf')
# Out:
# Scaffold of default

# %%
plt.figure(figsize=(35,35))
v.infer({'kernel': 'draw_scaffold', 'scope': 'scope_w', 'block' : 1, 'transitions': 1})
print 'Scaffold of w 1'
#plt.savefig('/Users/yutian/Desktop/scaffold_dpmlr_scope_w_1.png')
# Out:
# Scaffold of w 1

# %%
plt.figure(figsize=(20,20))
v.infer({'kernel': 'draw_scaffold', 'scope': 'scope_z', 'block' : 9, 'transitions': 1})
print 'Scaffold of z'
#plt.savefig('/Users/yutian/Desktop/scaffold_dpmlr_scope_z.pdf')
# Out:
# Scaffold of z

# %%
trace = v.sivm.core_sivm.engine.traces[0]
node = list(trace.scopes['scope_z'][0])[0]
r = list(list(list(list(node.children)[0].children)[0].children)[0].children)[1]
str(trace.valueAt(r).esrs)
# Out:
# "[ESR([Atom(1)], ['memoizedSP', ['quote', Atom(1)]], <venture.lite.env.VentureEnvironment object at 0x1101c5310>, None, None)]"

# %%
trace = v.sivm.core_sivm.engine.traces[0]
node = list(trace.scopes['scope_z'][1])[0]
r = list(list(list(list(node.children)[0].children)[0].children)[0].children)[0]
request_old = trace.valueAt(r)
str(trace.valueAt(r).esrs)
# Out:
# "[ESR([Atom(2)], ['memoizedSP', ['quote', Atom(2)]], <venture.lite.env.VentureEnvironment object at 0x11007eed0>, None, None)]"

# %%
from venture.lite.detach import unapplyPSP
from venture.lite.regen import applyPSP
from venture.lite.scaffold import Scaffold
from venture.lite.omegadb import OmegaDB

# %%
request_old.esrs[0]
# Out:
# ESR([Atom(2)], ['memoizedSP', ['quote', Atom(2)]], <venture.lite.env.VentureEnvironment object at 0x11007eed0>, None, None)

# %%
trace.valueAt(r).esrs[0].env.frame
# Out:
# {'memoizedSP': <venture.lite.node.OutputNode at 0x1100f4d50>}

# %%
applyPSP(trace,r,Scaffold(),False,OmegaDB(),{})
# Out:
# 0

# %%
plt.figure(figsize=(35,35))
v.infer({'kernel': 'draw_scaffold', 'scope': 'scope_alpha', 'block' : 'all', 'transitions': 1})
print 'Scaffold of alpha'
plt.savefig('/Users/yutian/Desktop/scaffold_dpmlr_scope_alpha.pdf')
# Out:
# Scaffold of alpha

# %%
plt.figure(figsize=(35,35))
v.infer({'kernel': 'draw_scaffold', 'scope': 'scope_y', 'block' : 'all', 'transitions': 1})
print 'Scaffold of y'
plt.savefig('/Users/yutian/Desktop/scaffold_dpmlr_scope_y.pdf')
# Out:
# Scaffold of y

# %% [markdown]
# ## VentureUnit

# %%
import ipdb
from venture import shortcuts
from venture.unit import VentureUnit
class DPMBayesLogitRegress(VentureUnit):
    def makeAssumes(self):
        D = self.parameters['features']
        self.assume('D', D)
        self.assume('mu', '(zeros_array (+ D 1))')
        self.assume('Sigma', '(diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (+ D 1))))')
        self.assume('alpha', '(scope_include (quote scope_alpha) 0 (uniform_continuous .5 1))')
        self.assume('crp', '(make_crp alpha)')
        self.assume('z', '(mem (lambda (i) (scope_include (quote scope_z) i (crp))))')
        self.assume('w', '(mem (lambda (z) (scope_include (quote scope_w) z (multivariate_normal mu Sigma))))')
        self.assume('f_x', '(lambda (x i) (dot_product (cat_array (array 1) x) (w (z i))))')
        self.assume('y_x', '(lambda (x i) (scope_include (quote scope_y) i (bernoulli (/ 1 (+ 1 (exp (- 0 (f_x x i))))))))')
        
    def makeObserves(self):
        N = self.parameters['observations']
        xs = self.parameters['xs']
        ys = self.parameters['ys']
        for n in xrange(N):
            self.observe('(y_x (array %s) %d)' % (' '.join(['%f' % x for x in xs[n]]), n), ys[n])

# ripl = shortcuts.make_church_prime_ripl()
ripl = shortcuts.make_lite_church_prime_ripl()

D = 2
N = 10
w = np.random.normal(0, np.sqrt(0.1), D + 1).tolist()
xs = np.random.normal(0, 1, [N, D])
fs = xs.dot(w[1:]) + w[0]
ys = np.random.random(N) < 1 / (1 + np.exp(-fs))
xs = xs.tolist()
ys = ys.tolist()

print 'w: ', w
print 'y: ', ys

parameters = {'features' : D, 'observations' : N, 'xs' : xs, 'ys' : ys}
# Out:
# w:  [0.1675958756482819, 0.09026870921713752, -0.06923130466275353]
# y:  [True, False, True, False, True, True, True, False, True, False]
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
model = DPMBayesLogitRegress(ripl, parameters)
#history = model.runConditionedFromPrior(50, verbose=True)
#history = model.runFromJoint(50, verbose=True)
#history = model.sampleFromJoint(20, verbose=True)
# sample_hist, infer_hist, klHistory = model.computeJointKL(20, 10, verbose=True)
# klHistory.plot(fmt='png',directory='klHistory')
#history,_ = model.runFromConditional(100, verbose=True)
history,_ = model.runFromConditional(10, verbose=True, runs=1, infer='(mh global_var 0 3)')
history.plot(fmt='pdf',directory='figure_BayesLogitRegress_runFromConditional/')

#parameters = {'topics' : [4, 8], 'vocab' : 10, 'documents' : [8, 12], 'words_per_document' : [10, 100]}
#run_count = 0
#def runner(params):
#    print "Running setting " + str(run_count) + " of 8"
#    print params
#    return LDA(ripl, params).computeJointKL(20, 20, verbose=True)
#histories = productMap(parameters, runner)
#
#plotAsymptotics(parameters, histories, 'sweep_time', fmt='png', aggregate=True)

# %%
model = DPMBayesLogitRegress(ripl, parameters)

# %%
import ipdb
from venture import shortcuts
from venture.unit import Analytics
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
a = Analytics(v,queryExps=['(w 1)', '(w 2)', '(w 3)'])

# %%
history,_ = a.runFromConditional(5, verbose=True, runs=1, infer='(mh scope_w all 10)')
# Out:
# Starting run 0 of 1
# Running sweep 1 of 5
# Running sweep 2 of 5
# Running sweep 3 of 5
# Running sweep 4 of 5
# Running sweep 5 of 5

# %%
plot(np.array(history.nameToSeries['(w 1)'][0].values));

# %%
history.plot()
# Out:
# History dumped to run_from_conditional_venture_random_seed=1//run_from_conditional using pickle
# plots written to run_from_conditional_venture_random_seed=1/

# %%
history,_ = model.runFromConditional(5, verbose=True, runs=1, infer='(mh scope_w 1 1)')
# Out:
# Starting run 0 of 1
# Running sweep 1 of 5
# Running sweep 2 of 5
# Running sweep 3 of 5
# Running sweep 4 of 5
# Running sweep 5 of 5

# %%
for i in range(len(history.nameToSeries['w'])):
    plot([v[0] for v in history.nameToSeries['w'][i].values])
    plot([v[1] for v in history.nameToSeries['w'][i].values])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-9690e584d8aa> in <module>()
#       1 for i in range(len(history.nameToSeries['w'])):
# ----> 2     plot([v[0] for v in history.nameToSeries['w'][i].values])
#       3     plot([v[1] for v in history.nameToSeries['w'][i].values])
#
# /usr/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2985         ax.hold(hold)
#    2986     try:
# -> 2987         ret = ax.plot(*args, **kwargs)
#    2988         draw_if_interactive()
#    2989     finally:
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4136
#    4137         for line in self._get_lines(*args, **kwargs):
# -> 4138             self.add_line(line)
#    4139             lines.append(line)
#    4140
#
# ...

# %%
history,_ = model.runFromConditional(20, verbose=True, runs=1, infer='(subsampled_mh scope_w 1 1 1 3 .01)')
# Out:
# Starting run 0 of 1
# Running sweep 1 of 20
# Running sweep 2 of 20
# Running sweep 3 of 20
# Running sweep 4 of 20
# Running sweep 5 of 20
# Running sweep 6 of 20
# Running sweep 7 of 20
# Running sweep 8 of 20
# Running sweep 9 of 20
# Running sweep 10 of 20
# Running sweep 11 of 20
# Running sweep 12 of 20
# Running sweep 13 of 20
# Running sweep 14 of 20
# Running sweep 15 of 20
# Running sweep 16 of 20
# Running sweep 17 of 20
# Running sweep 18 of 20
# Running sweep 19 of 20
# Running sweep 20 of 20
