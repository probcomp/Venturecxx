# %% [markdown]
# # Subsampled MH for DP Mixture of Logistic Regression Experts

# %%
from venture.venturemagics.ip_parallel import *
import numpy as np
import ipdb

# %%
# Run infer with the old kernel.
v=MRipl(1,backend='lite',local_mode=True)

# %%
D = 2
N = 10
w = np.random.normal(0, np.sqrt(0.1), D + 1).tolist()
xs = np.random.normal(0, 1, [N, D])
ys = np.random.random(N) < (xs.dot(w[1:]) + w[0])
xs = xs.tolist()
ys = ys.tolist()

# %%
# %%venture v
# [clear]
# [assume D 2]
# [assume mu (zeros_array (+ D 1))]
# [assume Sigma (diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (+ D 1))))]
# [assume alpha (uniform_continuous .01 1)]
# [assume crp (make_crp alpha) ]
# [assume z (mem (lambda (i) (crp) ) ) ]
# [assume w (mem (lambda (z) (scope_include (quote global_var) z (multivariate_normal mu Sigma))))]
# [assume x (mem (lambda (i dim) (normal (mu (z i) dim) (sig (z i) dim)))  ) ]
# [assume f_x (lambda (x i) (dot_product (cat_array (array 1) x) (w (z i))))]
# [assume y_x (lambda (x i) (bernoulli (/ 1 (+ 1 (exp (- 0 (f_x x i)))))))]
# Out:
# Total transitions set to 0

# %%
for d in v.local_ripls[0].list_directives():
    print directive_split(d)
# Out:
# ('D', '2.0')
# ('mu', '(zeros_array (add D 1.0))')
# ('Sigma', '(diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (add D 1.0))))')
# ('alpha', '(uniform_continuous 0.5 1.0)')
# ('crp', '(make_crp alpha)')
# ('z', '(mem (lambda (i) (crp)))')
# ('w', '(mem (lambda (z) (scope_include (quote global_var) z (first (pair (multivariate_normal mu Sigma) 1.0)))))')
# ('x', '(mem (lambda (i dim) (normal (mu (z i) dim) (sig (z i) dim))))')
# ('f_x', '(lambda (x i) (dot_product (cat_array (array 1.0) x) (w (z i))))')
# ('y_x', '(lambda (x i) (bernoulli (div 1.0 (add 1.0 (exp (sub 0.0 (f_x x i)))))))')

# %%
for n in xrange(N):
    v.observe('(scope_include (quote to_subsample) %d (y_x (array %s) %d))' \
              % (n, ' '.join(['%f' % x for x in xs[n]]), n), ys[n])

# %%
zs = [v.sample('(z %d)' % n)[0] for n in xrange(N)]
print zs
# Out:
# [1, 1, 1, 1, 2, 2, 1, 2, 1, 1]

# %%
for z in range(1,max(zs)+1):
    print v.sample('(w %d)' % z)[0]
# Out:
# [0.2723487385540072, 0.3256746242673148, -0.10211138458113368]
# [0.7930163410598944, -0.21058090695208007, 0.1547553854713398]

# %%
xt = zip(*[xs[i] for i in range(len(xs)) if ys[i]])
plot(xt[0], xt[1], 'gx')
xt = zip(*[xs[i] for i in range(len(xs)) if not ys[i]])
plot(xt[0], xt[1], 'rx')

# %% [markdown]
# ### Plot the scaffold

# %%
import venture.lite.node as nd

# %%
trace = v.local_ripls[0].sivm.core_sivm.engine.traces[0]
n = next(iter(trace.getNodesInBlock('global_var',1)))
n2 = [nn for nn in n.children if isinstance(nn, nd.OutputNode)][0]
n3 = next(iter(n2.children))
print n3.operatorNode.value.makerNode.madeSP.requestPSP.exp
n4 = next(iter(n3.children))
n4.operatorNode.value.makerNode.madeSP.requestPSP
# Out:
# ['scope_include', ['quote', 'global_var'], 'z', ['multivariate_normal', 'mu', 'Sigma']]

# %%
nw = trace.globalEnv.findSymbol('w')
nw.operatorNode.value.makerNode.madeSP.outputPSP.psp

# %%
plt.figure(figsize=(35,35))
v.infer({'kernel': 'draw_scaffold', 'scope': 'default', 'block' : 'all', 'transitions': 1})
# Out:
# [None]

# %%
debug
# Out:
# > /usr/local/lib/python2.7/site-packages/venture/lite/smap.py(9)__getitem__()
#       8   def __getitem__(self,k):
# ----> 9     return self.a[self.d[k]][1]
#      10
# ipdb> k
# 0
# ipdb> up
# > /usr/local/lib/python2.7/site-packages/venture/lite/trace.py(244)getNodesInBlock()
#     243   def getNodesInBlock(self,scope,block):
# --> 244     nodes = self.scopes[scope][block]
#     245     if scope == "default": return nodes
# ipdb> scope
# 'global_var'
# ipdb> block
# 0
# ipdb> self.scopes[scope]
# SMap: {1: set([<venture.lite.node.OutputNode object at 0x10d628d90>]), 2: set([<venture.lite.node.OutputNode object at 0x10d59b310>]), 3: set([<venture.lite.node.OutputNode object at 0x10d639710>])}
# ipdb> EOF

# %%
plt.figure(figsize=(20,20))
v.infer({'kernel': 'draw_subsampled_scaffold', 'scope': 'global_var', 'block' : 0, 'transitions': 1, 'scope_to_subsample': 'to_subsample'})

# %% [markdown]
# ## VentureUnit

# %%
from venture import shortcuts
from venture.unit import VentureUnit
class BayesLogitRegress(VentureUnit):
    def makeAssumes(self):
        D = self.parameters['features']
        self.assume('D', D)
        self.assume('mu', '(zeros_array (+ D 1))')
        self.assume('Sigma', '(diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (+ D 1))))')
        self.assume('w', '(scope_include (quote global_var) 0 (multivariate_normal mu Sigma))')
        self.assume('f_x', '(lambda (x) (dot_product (cat_array (array 1) x) w))')
        self.assume('y_x', '(lambda (x) (bernoulli (/ 1 (+ 1 (exp (- 0 (f_x x)))))))')

    def makeObserves(self):
        N = self.parameters['observations']
        xs = self.parameters['xs']
        ys = self.parameters['ys']
        for n in xrange(N):
            self.observe('(scope_include (quote to_subsample) %d (y_x (array %s)))' \
                         % (n, ' '.join(['%f' % x for x in xs[n]])), ys[n])


# ripl = shortcuts.make_church_prime_ripl()
ripl = shortcuts.make_lite_church_prime_ripl()

D = 1
N = 30

w = np.random.normal(0, np.sqrt(0.1), D + 1).tolist()
xs = np.random.normal(0, 1, [N, D])
ys = np.random.random(N) < (xs.dot(w[1:]) + w[0])
xs = xs.tolist()
ys = ys.tolist()

print 'w: ', w

parameters = {'features' : D, 'observations' : N, 'xs' : xs, 'ys' : ys}
# Out:
# w:  [0.01483849066716978, 0.01908699009580508]
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
model = BayesLogitRegress(ripl, parameters)
#history = model.runConditionedFromPrior(50, verbose=True)
#history = model.runFromJoint(50, verbose=True)
#history = model.sampleFromJoint(20, verbose=True)
# sample_hist, infer_hist, klHistory = model.computeJointKL(20, 10, verbose=True)
# klHistory.plot(fmt='png',directory='klHistory')
#history,_ = model.runFromConditional(100, verbose=True)
history,_ = model.runFromConditional(10, verbose=True, runs=1, infer='(mh global_var 0 3)')
history.plot(fmt='pdf',directory='figure_BayesLogitRegress_runFromConditional/')

#parameters = {'topics' : [4, 8], 'vocab' : 10, 'documents' : [8, 12], 'words_per_document' : [10, 100]}
#run_count = 0
#def runner(params):
#    print "Running setting " + str(run_count) + " of 8"
#    print params
#    return LDA(ripl, params).computeJointKL(20, 20, verbose=True)
#histories = productMap(parameters, runner)
#
#plotAsymptotics(parameters, histories, 'sweep_time', fmt='png', aggregate=True)

# %%
model = BayesLogitRegress(ripl, parameters)

# %%
history,_ = model.runFromConditional(5, verbose=True, runs=1, infer='(mh global_var 0 1)')
# Out:
# Starting run 0 of 1
# Running sweep 1 of 5
# accepted,
#  VentureArray([VentureNumber(0.656913869329), VentureNumber(-0.605778758536)])
# 0.910287207202 0 0 0.910287207202
# Running sweep 2 of 5
# accepted,
#  VentureArray([VentureNumber(0.29526726975), VentureNumber(0.113150782007)])
# 10.4426438213 0 0 10.4426438213
# Running sweep 3 of 5
# accepted,
#  VentureArray([VentureNumber(-0.567392121572), VentureNumber(0.489925567707)])
# 11.3488133976 0 0 11.3488133976
# Running sweep 4 of 5
# rejected,
#  VentureArray([VentureNumber(0.152747549904), VentureNumber(-0.0579478107899)])
# -9.70864364322 0 0 -9.70864364322
# Running sweep 5 of 5
# rejected,
#  VentureArray([VentureNumber(0.805883150173), VentureNumber(-0.407279976854)])
# -23.2055544746 0 0 -23.2055544746

# %%
for i in range(len(history.nameToSeries['w'])):
    plot([v[0] for v in history.nameToSeries['w'][i].values])
    plot([v[1] for v in history.nameToSeries['w'][i].values])

# %%
history,_ = model.runFromConditional(3, verbose=True, runs=1, infer='(subsampled_mh global_var 0 10 w 1 3 .01)')
# Out:
# Starting run 0 of 1
# Running sweep 1 of 3
# accepted,
#  VentureArray([VentureNumber(0.656913869329), VentureNumber(-0.605778758536)])
# 2.95142750682 0 0 0.098380916894 0
# accepted,  VentureArray([VentureNumber(0.29526726975), VentureNumber(0.113150782007)])
# 22.7545965409 0 0 0.758486551362 0
# accepted,  VentureArray([VentureNumber(-0.567392121572), VentureNumber(0.489925567707)])
# 13.688568587 0 0 0.456285619566 0
# rejected,
#  VentureArray([VentureNumber(0.152747549904), VentureNumber(-0.0579478107899)])
# -12.9785114061 0 0 -0.432617046871 0
# rejected,  VentureArray([VentureNumber(0.805883150173), VentureNumber(-0.407279976854)])
# -29.6804966448 0 0 -0.989349888159 0
# rejected,  VentureArray([VentureNumber(-0.0318663046206), VentureNumber(0.424449462833)])
# -6.2348123257 0 0 -0.207827077523 0
# rejected,
#  VentureArray([VentureNumber(0.191748351764), VentureNumber(1.16989982972)])
# -7.59346017049 0 0 -0.253115339016 0
# accepted,
#  VentureArray([VentureNumber(-1.26240851008), VentureNumber(-0.559160009607)])
# 1.66930840977 0 0 0.055643613659 0
# rejected,  VentureArray([VentureNumber(0.412095565531), VentureNumber(0.0612428679307)])
# -16.9089387248 0 0 -0.563631290828 0
# rejected,  VentureArray([VentureNumber(0.304671907294), VentureNumber(0.104102879113)])
# -14.6202954513 0 0 -0.487343181709 0
# Make consistent after  10  transitions
# Running sweep 2 of 3
# rejected,
#  VentureArray([VentureNumber(-0.175402710359), VentureNumber(0.375182698103)])
# -5.79529498571 0 0 -0.193176499524 0
# rejected,  VentureArray([VentureNumber(-0.491320178446), VentureNumber(-0.314678445115)])
# -6.52411426102 0 0 -0.217470475367 0
# rejected,
#  VentureArray([VentureNumber(-0.337960975675), VentureNumber(0.206382925352)])
# -4.20939715941 0 0 -0.140313238647 0
# rejected,  VentureArray([VentureNumber(0.313227499591), VentureNumber(-0.598775834175)])
# -22.4594203882 0 0 -0.748647346273 0
# rejected,  VentureArray([VentureNumber(0.476185966871), VentureNumber(-0.0351243714763)])
# -19.1009583149 0 0 -0.636698610498 0
# rejected,
#  VentureArray([VentureNumber(-0.451199262117), VentureNumber(0.832337681626)])
# -4.4046146712 0 0 -0.14682048904 0
# rejected,
#  VentureArray([VentureNumber(-0.398985269622), VentureNumber(0.891159287854)])
# -5.11423768728 0 0 -0.170474589576 0
# rejected,  VentureArray([VentureNumber(1.06352254166), VentureNumber(0.312158296764)])
# -26.8171721557 0 0 -0.893905738523 0
# rejected,
#  VentureArray([VentureNumber(-0.0396719448274), VentureNumber(0.208838557583)])
# -6.32115589132 0 0 -0.210705196377 0
# rejected,
#  VentureArray([VentureNumber(0.472927692273), VentureNumber(0.979983016682)])
# -12.6393343469 0 0 -0.421311144895 0
# Make consistent after  10  transitions
# Running sweep 3 of 3
# rejected,  VentureArray([VentureNumber(-0.381898308357), VentureNumber(-0.1179497213)])
# -6.41176010757 0 0 -0.213725336919 0
# rejected,  VentureArray([VentureNumber(0.37515252266), VentureNumber(-0.918670696838)])
# -27.7674900499 0 0 -0.925583001662 0
# rejected,  VentureArray([VentureNumber(0.0105413281461), VentureNumber(-0.276687812519)])
# -13.4659470351 0 0 -0.44886490117 0
# accepted,
#  VentureArray([VentureNumber(-1.17819844636), VentureNumber(-0.526727309196)])
# -0.552800775085 0 0 -0.0184266925028 0
# rejected,  VentureArray([VentureNumber(-0.528241068626), VentureNumber(-0.269073553023)])
# -5.16438305636 0 0 -0.172146101879 0
# rejected,  VentureArray([VentureNumber(-0.370505019213), VentureNumber(-0.344176861641)])
# -7.80694808226 0 0 -0.260231602742 0
# rejected,
#  VentureArray([VentureNumber(-0.187920533854), VentureNumber(0.164143250735)])
# -5.46514665706 0 0 -0.182171555235 0
# rejected,
#  VentureArray([VentureNumber(0.11800036789), VentureNumber(0.594512378708)])
# -8.37873257937 0 0 -0.279291085979 0
# rejected,  VentureArray([VentureNumber(1.39131971263), VentureNumber(-0.367449293886)])
# -43.0892929315 0 0 -1.43630976438 0
# rejected,  VentureArray([VentureNumber(0.221690885759), VentureNumber(-0.748885169313)])
# -21.9212198554 0 0 -0.730707328512 0
# Make consistent after  10  transitions

# %%
for i in range(len(history.nameToSeries['w'])):
    plot([v[0] for v in history.nameToSeries['w'][i].values])
    plot([v[1] for v in history.nameToSeries['w'][i].values])
