# %% [markdown]
# # Subsampled MH for Bayesian Logistic Regression

# %%
import numpy as np
import ipdb
from venture.venturemagics.ip_parallel import *
from venture.unit import Analytics
make_ripl = make_l_riple

# %%
v=make_ripl()

# %% [markdown]
# #### Synthetic Data

# %%
D = 3
N = 100
w = np.random.normal(0, np.sqrt(0.1), D + 1).tolist()
xs = np.random.normal(0, 1, [N, D])
fs = xs.dot(w[1:]) + w[0]
ys = np.random.random(N) < 1 / (1 + np.exp(-fs))
xs = xs.tolist()
ys = ys.tolist()

# %% [markdown]
# #### Load MNIST Data

# %%
from load_data import loadData
data_file = 'data/input/mnist_D50_7_9.mat'
N, D, X, Y = loadData(data_file)

# %% [markdown]
# #### full primitives

# %%
# %%venture v
# [clear]
# [assume D 3]
# [assume mu (zeros_array (+ D 1))]
# [assume Sigma (diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (+ D 1))))]
# [assume w (scope_include (quote global_var) 0 (multivariate_normal mu Sigma))]
# [assume f_x (lambda (x) (dot_product (cat_array (array 1) x) w))]
# [assume y_x (lambda (x) (bernoulli (/ 1 (+ 1 (exp (- 0 (f_x x)))))))]

# %% [markdown]
# #### logistic function f(x) = 1/(1+exp(-x))

# %%
# %%venture v
# [clear]
# [assume D 3]
# [assume mu (zeros_array (+ D 1))]
# [assume Sigma (diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (+ D 1))))]
# [assume w (scope_include (quote global_var) 0 (multivariate_normal mu Sigma))]
# [assume f_x (lambda (x) (dot_product (cat_array (array 1) x) w))]
# [assume y_x (lambda (x) (bernoulli (logistic (f_x x))))]

# %% [markdown]
# #### linear_logistic function f(w, x) = 1/(1+exp(-(w[0] + w[1:].dot(x))

# %%
prog = """
[clear]
[assume D %d]
[assume mu (zeros_array (+ D 1))]
[assume Sigma (diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (+ D 1))))]
[assume w (scope_include (quote w) 0 (multivariate_normal mu Sigma))]
[assume y_x (lambda (x) (bernoulli (linear_logistic w x)))]
""" % D
v.execute_program(prog);

# %%
for n in xrange(N):
    v.observe('(scope_include (quote y) %d (y_x (array %s)))' \
              % (n, ' '.join(['%f' % x for x in X[n]])), Y[n])

# %%
v.infer('(mh global_var all 3 true .1)')

# %%
v.infer('(subsampled_mh global_var all 1 2 3 .01 true .1 true)')
# Out:
# constructScaffold: update_value
# constructScaffold: update_value
# constructScaffold: update_value
# constructScaffold: update_value
# constructScaffold: update_value
# constructScaffold: update_value
# constructScaffold: update_value
# constructScaffold: update_value
# constructScaffold: update_value
# constructScaffold: update_value

# %%
v.infer({'kernel':'subsampled_mh', 'scope':'global_var', 'block':0, 'transitions':3, 'scope_symbol':'w', 'Nbatch':2, 'k0':2, 'epsilon':0.001, 'useDeltaKernels':True})

# %%
ipdb.runcall(v.infer,'(mh global_var all 3 true .1 true)')
# Out:
# > /usr/local/lib/python2.7/site-packages/venture/ripl/ripl.py(399)infer()
#     398     def infer(self, params=None):
# --> 399         self.execute_instruction({'instruction':'infer', 'params': self.parseInferParams(params)})
#     400
# ipdb> b venture/engin/engin:147
# ***  'venture/engin/engin' not found from sys.path
# ipdb> b venture/engin/engine:147
# ***  'venture/engin/engine' not found from sys.path
# ipdb> b venture/engine/engine:147
# Breakpoint 1 at /usr/local/lib/python2.7/site-packages/venture/engine/engine.py:147
# ipdb> c
# > /usr/local/lib/python2.7/site-packages/venture/engine/engine.py(147)incorporate()
#     146     for i,trace in enumerate(self.traces):
# 1-> 147       self.weights[i] += trace.makeConsistent()
#     148
# ipdb> s
# --Call--
# > /usr/local/lib/python2.7/site-packages/venture/lite/trace.py(294)makeConsistent()
#     293
# --> 294   def makeConsistent(self):
#     295     weight = 0
# ipdb> n
# > /usr/local/lib/python2.7/site-packages/venture/lite/trace.py(295)makeConsistent()
#     294   def makeConsistent(self):
# --> 295     weight = 0
#     296     for node,val in self.unpropagatedObservations.iteritems():
# ipdb> n
# > /usr/local/lib/python2.7/site-packages/venture/lite/trace.py(296)makeConsistent()
#     295     weight = 0
# --> 296     for node,val in self.unpropagatedObservations.iteritems():
#     297       appNode = self.getOutermostNonReferenceApplication(node)
# ipdb> n
# > /usr/local/lib/python2.7/site-packages/venture/lite/trace.py(297)makeConsistent()
#     296     for node,val in self.unpropagatedObservations.iteritems():
# --> 297       appNode = self.getOutermostNonReferenceApplication(node)
#     298 #      print "PROPAGATE",node,appNode
# ipdb> n
# > /usr/local/lib/python2.7/site-packages/venture/lite/trace.py(299)makeConsistent()
#     298 #      print "PROPAGATE",node,appNode
# --> 299       scaffold = constructScaffold(self,[set([appNode])])
#     300       rhoWeight,_ = detachAndExtract(self,scaffold.border[0],scaffold)
# ipdb> s
# --Call--
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(103)constructScaffold()
#     102
# --> 103 def constructScaffold(trace,setsOfPNodes,useDeltaKernels = False, deltaKernelArgs = None, updateValue = False):
#     104   while True:
# ipdb> n
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(104)constructScaffold()
#     103 def constructScaffold(trace,setsOfPNodes,useDeltaKernels = False, deltaKernelArgs = None, updateValue = False):
# --> 104   while True:
#     105     cDRG,cAbsorbing,cAAA = set(),set(),set()
# ipdb> n
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(105)constructScaffold()
#     104   while True:
# --> 105     cDRG,cAbsorbing,cAAA = set(),set(),set()
#     106     indexAssignments = {}
# ipdb>
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(106)constructScaffold()
#     105     cDRG,cAbsorbing,cAAA = set(),set(),set()
# --> 106     indexAssignments = {}
#     107     assert isinstance(setsOfPNodes,list)
# ipdb>
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(107)constructScaffold()
#     106     indexAssignments = {}
# --> 107     assert isinstance(setsOfPNodes,list)
#     108     for i in range(len(setsOfPNodes)):
# ipdb> setsOfPnodes
# *** NameError: name 'setsOfPnodes' is not defined
# ipdb> setsOfPNodes
# [set([<venture.lite.node.OutputNode object at 0x1120f1890>])]
# ipdb> n
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(108)constructScaffold()
#     107     assert isinstance(setsOfPNodes,list)
# --> 108     for i in range(len(setsOfPNodes)):
#     109       assert isinstance(setsOfPNodes[i],set)
# ipdb> n
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(109)constructScaffold()
#     108     for i in range(len(setsOfPNodes)):
# --> 109       assert isinstance(setsOfPNodes[i],set)
#     110       extendCandidateScaffold(trace,setsOfPNodes[i],cDRG,cAbsorbing,cAAA,indexAssignments,i)
# ipdb>
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(110)constructScaffold()
#     109       assert isinstance(setsOfPNodes[i],set)
# --> 110       extendCandidateScaffold(trace,setsOfPNodes[i],cDRG,cAbsorbing,cAAA,indexAssignments,i)
#     111
# ipdb>
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(108)constructScaffold()
#     107     assert isinstance(setsOfPNodes,list)
# --> 108     for i in range(len(setsOfPNodes)):
#     109       assert isinstance(setsOfPNodes[i],set)
# ipdb>
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(112)constructScaffold()
#     111
# --> 112     brush = findBrush(trace,cDRG)
#     113     drg,absorbing,aaa = removeBrush(cDRG,cAbsorbing,cAAA,brush)
# ipdb>
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(113)constructScaffold()
#     112     brush = findBrush(trace,cDRG)
# --> 113     drg,absorbing,aaa = removeBrush(cDRG,cAbsorbing,cAAA,brush)
#     114     border = findBorder(trace,drg,absorbing,aaa)
# ipdb>
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(114)constructScaffold()
#     113     drg,absorbing,aaa = removeBrush(cDRG,cAbsorbing,cAAA,brush)
# --> 114     border = findBorder(trace,drg,absorbing,aaa)
#     115     regenCounts = computeRegenCounts(trace,drg,absorbing,aaa,border,brush)
# ipdb>
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(115)constructScaffold()
#     114     border = findBorder(trace,drg,absorbing,aaa)
# --> 115     regenCounts = computeRegenCounts(trace,drg,absorbing,aaa,border,brush)
#     116     lkernels = loadKernels(trace,drg,aaa,useDeltaKernels,deltaKernelArgs)
# ipdb>
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(116)constructScaffold()
#     115     regenCounts = computeRegenCounts(trace,drg,absorbing,aaa,border,brush)
# --> 116     lkernels = loadKernels(trace,drg,aaa,useDeltaKernels,deltaKernelArgs)
#     117     borderSequence = assignBorderSequnce(border,indexAssignments,len(setsOfPNodes))
# ipdb>
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(117)constructScaffold()
#     116     lkernels = loadKernels(trace,drg,aaa,useDeltaKernels,deltaKernelArgs)
# --> 117     borderSequence = assignBorderSequnce(border,indexAssignments,len(setsOfPNodes))
#     118     scaffold = Scaffold(setsOfPNodes,regenCounts,absorbing,aaa,borderSequence,lkernels,brush)
# ipdb>
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(118)constructScaffold()
#     117     borderSequence = assignBorderSequnce(border,indexAssignments,len(setsOfPNodes))
# --> 118     scaffold = Scaffold(setsOfPNodes,regenCounts,absorbing,aaa,borderSequence,lkernels,brush)
#     119     if not updateValue or not updateValuesAtScaffold(trace,scaffold,updatedNodes,useDeltaKernels,deltaKernelArgs):
# ipdb>
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(119)constructScaffold()
#     118     scaffold = Scaffold(setsOfPNodes,regenCounts,absorbing,aaa,borderSequence,lkernels,brush)
# --> 119     if not updateValue or not updateValuesAtScaffold(trace,scaffold,updatedNodes,useDeltaKernels,deltaKernelArgs):
#     120       break
# ipdb> scaffold.border
# [[<venture.lite.node.RequestNode object at 0x1120f1110>, <venture.lite.node.OutputNode object at 0x1120f1610>]]
# ipdb> updateValue
# False
# ipdb> n
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(120)constructScaffold()
#     119     if not updateValue or not updateValuesAtScaffold(trace,scaffold,updatedNodes,useDeltaKernels,deltaKernelArgs):
# --> 120       break
#     121   return Scaffold
# ipdb> n
# > /usr/local/lib/python2.7/site-packages/venture/lite/scaffold.py(121)constructScaffold()
#     120       break
# --> 121   return Scaffold
#     122
# ipdb> EOF

# %%
import cProfile

# %%
cProfile.run("v.infer('(subsampled_mh global_var 0 10 2 3 0.001 True .1)')", 'infer_stats')

# %%
def runrepeated(n, cmd):
    v.infer(cmd)

# %%
cProfile.run('runrepeated(1, "(subsampled_mh global_var 0 %s 2 3 0.001 True .1)")' % 100, 'infer_stats')

# %%
import pstats
p = pstats.Stats('infer_stats')

# %%
p.strip_dirs().sort_stats('cumulative').print_stats('(subsampled_mh.py|regen.py|detach.py)')
# Out:
# Fri May 23 11:12:48 2014    infer_stats
#
#          68469853 function calls (67395353 primitive calls) in 54.616 seconds
#
#    Ordered by: cumulative time
#    List reduced from 286 to 41 due to restriction <'(subsampled_mh.py|regen.py|detach.py)'>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       100    0.150    0.001   54.276    0.543 subsampled_mh.py:421(subsampledMixMH)
#      7380    0.093    0.000   49.792    0.007 subsampled_mh.py:581(evalOneLocalSection)
#     14998    0.221    0.000   26.709    0.002 regen.py:10(regenAndAttach)
#    104158    0.539    0.000   26.365    0.000 regen.py:56(attach)
#     14998    0.225    0.000   23.513    0.002 detach.py:7(detachAndExtract)
#    104158    0.425    0.000   23.196    0.000 detach.py:32(detach)
# 208454/104296    0.753    0.000   20.642    0.000 regen.py:64(regenParents)
# 640912/283030    1.781    0.000   19.870    0.000 regen.py:77(regen)
# 208454/104296    0.855    0.000   17.510    0.000 detach.py:45(extractParents)
# 640912/283030    1.753    0.000   16.900    0.000 detach.py:59(extract)
#     89436    0.660    0.000   11.416    0.000 regen.py:135(applyPSP)
#     89436    0.685    0.000    9.677    0.000 detach.py:120(unapplyPSP)
#      7480    0.039    0.000    3.384    0.000 subsampled_mh.py:560(sampleLocalIndex)
#      7480    0.099    0.000    3.343    0.000 subsampled_mh.py:75(constructScaffold)
#      7480    0.396    0.000    2.686    0.000 subsampled_mh.py:113(extendCandidateScaffold)
#   1281824    0.436    0.000    0.436    0.000 subsampled_mh.py:28(isResampling)
#         1    0.001    0.001    0.382    0.382 subsampled_mh.py:605(makeConsistent)
#     52461    0.151    0.000    0.222    0.000 subsampled_mh.py:132(addResamplingNode)
#      7581    0.028    0.000    0.204    0.000 subsampled_mh.py:151(findBrush)
#       100    0.000    0.000    0.201    0.002 subsampled_mh.py:635(propose)
#      7581    0.044    0.000    0.139    0.000 subsampled_mh.py:191(findBorder)
#    387188    0.118    0.000    0.118    0.000 subsampled_mh.py:30(isAAA)
#     52562    0.053    0.000    0.088    0.000 subsampled_mh.py:187(hasChildInAorD)
#       100    0.000    0.000    0.087    0.001 subsampled_mh.py:572(prepare)
#    208592    0.083    0.000    0.083    0.000 subsampled_mh.py:29(isAbsorbing)
#      7581    0.059    0.000    0.078    0.000 subsampled_mh.py:202(computeRegenCounts)
#        38    0.000    0.000    0.065    0.002 subsampled_mh.py:599(reject)
#    178872    0.065    0.000    0.065    0.000 subsampled_mh.py:31(hasLKernel)
#     52461    0.045    0.000    0.058    0.000 subsampled_mh.py:145(addAbsorbingNode)
#      7581    0.037    0.000    0.053    0.000 subsampled_mh.py:237(assignBorderSequnce)
#      7581    0.031    0.000    0.038    0.000 subsampled_mh.py:179(removeBrush)
#       101    0.002    0.000    0.029    0.000 subsampled_mh.py:525(sampleGlobalIndex)
#      7581    0.015    0.000    0.023    0.000 subsampled_mh.py:226(loadKernels)
#      7581    0.022    0.000    0.022    0.000 subsampled_mh.py:15(__init__)
#       101    0.002    0.000    0.017    0.000 subsampled_mh.py:51(constructScaffoldGlobalSection)
#       101    0.001    0.000    0.005    0.000 subsampled_mh.py:91(extendCandidateScaffoldGlobalSection)
#      7581    0.003    0.000    0.003    0.000 subsampled_mh.py:227(<dictcomp>)
#       200    0.000    0.000    0.000    0.000 subsampled_mh.py:565(logDensityOfGlobalIndex)
#       101    0.000    0.000    0.000    0.000 subsampled_mh.py:517(__init__)
#       276    0.000    0.000    0.000    0.000 subsampled_mh.py:32(getLKernel)
#        62    0.000    0.000    0.000    0.000 subsampled_mh.py:598(accept)
# <pstats.Stats instance at 0x11510a440>

# %%
p.strip_dirs().sort_stats('cumulative').print_stats('(subsampled_mh.py|regen.py|detach.py)')
# Out:
# Fri May 23 11:27:00 2014    infer_stats
#
#          34911236 function calls (34391040 primitive calls) in 35.577 seconds
#
#    Ordered by: cumulative time
#    List reduced from 309 to 42 due to restriction <'(subsampled_mh.py|regen.py|detach.py)'>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       100    0.151    0.002   35.147    0.351 subsampled_mh.py:421(subsampledMixMH)
#      7058    0.097    0.000   31.637    0.004 subsampled_mh.py:581(evalOneLocalSection)
#     14452    0.176    0.000   17.498    0.001 regen.py:10(regenAndAttach)
#     57100    0.405    0.000   17.042    0.000 regen.py:56(attach)
#     14452    0.177    0.000   14.650    0.001 detach.py:7(detachAndExtract)
#     57100    0.281    0.000   14.259    0.000 detach.py:32(detach)
# 114536/57336    0.516    0.000   12.851    0.000 regen.py:64(regenParents)
# 316356/143340    1.157    0.000   12.363    0.000 regen.py:77(regen)
# 114536/57336    0.559    0.000   10.192    0.000 detach.py:45(extractParents)
# 316356/143340    1.103    0.000    9.836    0.000 detach.py:59(extract)
#     43220    0.425    0.000    6.909    0.000 regen.py:135(applyPSP)
#     43220    0.402    0.000    5.334    0.000 detach.py:120(unapplyPSP)
#      7158    0.037    0.000    2.253    0.000 subsampled_mh.py:560(sampleLocalIndex)
#      7158    0.102    0.000    2.215    0.000 subsampled_mh.py:75(constructScaffold)
#      7158    0.263    0.000    1.693    0.000 subsampled_mh.py:113(extendCandidateScaffold)
#    629312    0.283    0.000    0.283    0.000 subsampled_mh.py:28(isResampling)
#       100    0.001    0.000    0.243    0.002 subsampled_mh.py:635(propose)
#         1    0.001    0.001    0.223    0.223 subsampled_mh.py:605(makeConsistent)
#      7259    0.023    0.000    0.142    0.000 subsampled_mh.py:151(findBrush)
#     28733    0.103    0.000    0.141    0.000 subsampled_mh.py:132(addResamplingNode)
#       100    0.000    0.000    0.105    0.001 subsampled_mh.py:572(prepare)
#      7259    0.030    0.000    0.098    0.000 subsampled_mh.py:191(findBorder)
#    199840    0.077    0.000    0.077    0.000 subsampled_mh.py:30(isAAA)
#        36    0.000    0.000    0.076    0.002 subsampled_mh.py:599(reject)
#     28834    0.039    0.000    0.063    0.000 subsampled_mh.py:187(hasChildInAorD)
#    114272    0.055    0.000    0.055    0.000 subsampled_mh.py:29(isAbsorbing)
#      7259    0.041    0.000    0.054    0.000 subsampled_mh.py:202(computeRegenCounts)
#      7259    0.031    0.000    0.043    0.000 subsampled_mh.py:237(assignBorderSequnce)
#     85840    0.040    0.000    0.040    0.000 subsampled_mh.py:31(hasLKernel)
#     28733    0.033    0.000    0.039    0.000 subsampled_mh.py:145(addAbsorbingNode)
#       101    0.002    0.000    0.033    0.000 subsampled_mh.py:525(sampleGlobalIndex)
#      7259    0.025    0.000    0.032    0.000 subsampled_mh.py:179(removeBrush)
#      7259    0.016    0.000    0.025    0.000 subsampled_mh.py:226(loadKernels)
#      7259    0.023    0.000    0.023    0.000 subsampled_mh.py:15(__init__)
#       100    0.001    0.000    0.023    0.000 regen.py:30(constrain)
#       101    0.002    0.000    0.019    0.000 subsampled_mh.py:51(constructScaffoldGlobalSection)
#       101    0.001    0.000    0.006    0.000 subsampled_mh.py:91(extendCandidateScaffoldGlobalSection)
#      7259    0.003    0.000    0.003    0.000 subsampled_mh.py:227(<dictcomp>)
#       200    0.000    0.000    0.000    0.000 subsampled_mh.py:565(logDensityOfGlobalIndex)
#       101    0.000    0.000    0.000    0.000 subsampled_mh.py:517(__init__)
#       272    0.000    0.000    0.000    0.000 subsampled_mh.py:32(getLKernel)
#        64    0.000    0.000    0.000    0.000 subsampled_mh.py:598(accept)
# <pstats.Stats instance at 0x1099f55a8>

# %%
p.strip_dirs().sort_stats('cumulative').print_stats('(subsampled_mh.py|regen.py|detach.py)')
# Out:
# Fri May 23 11:25:28 2014    infer_stats
#
#          22372668 function calls (22122994 primitive calls) in 23.456 seconds
#
#    Ordered by: cumulative time
#    List reduced from 281 to 41 due to restriction <'(subsampled_mh.py|regen.py|detach.py)'>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       100    0.150    0.001   23.341    0.233 subsampled_mh.py:421(subsampledMixMH)
#      7612    0.094    0.000   20.607    0.003 subsampled_mh.py:581(evalOneLocalSection)
#     15459    0.147    0.000   11.417    0.001 regen.py:10(regenAndAttach)
#     46107    0.265    0.000   11.152    0.000 regen.py:56(attach)
#     15459    0.152    0.000    9.447    0.001 detach.py:7(detachAndExtract)
#     46107    0.230    0.000    9.216    0.000 detach.py:32(detach)
# 77025/46242    0.343    0.000    7.331    0.000 regen.py:64(regenParents)
# 201102/123267    0.710    0.000    6.907    0.000 regen.py:77(regen)
# 77025/46242    0.367    0.000    5.499    0.000 detach.py:45(extractParents)
# 201102/123267    0.696    0.000    5.181    0.000 detach.py:59(extract)
#     15594    0.161    0.000    3.566    0.000 regen.py:135(applyPSP)
#     15594    0.152    0.000    2.408    0.000 detach.py:120(unapplyPSP)
#      7712    0.035    0.000    1.443    0.000 subsampled_mh.py:560(sampleLocalIndex)
#      7712    0.106    0.000    1.407    0.000 subsampled_mh.py:75(constructScaffold)
#      7712    0.171    0.000    0.989    0.000 subsampled_mh.py:113(extendCandidateScaffold)
#       100    0.001    0.000    0.237    0.002 subsampled_mh.py:635(propose)
#    402204    0.181    0.000    0.181    0.000 subsampled_mh.py:28(isResampling)
#         1    0.001    0.001    0.163    0.163 subsampled_mh.py:605(makeConsistent)
#       100    0.000    0.000    0.102    0.001 subsampled_mh.py:572(prepare)
#     15525    0.063    0.000    0.088    0.000 subsampled_mh.py:132(addResamplingNode)
#      7813    0.018    0.000    0.085    0.000 subsampled_mh.py:151(findBrush)
#        35    0.000    0.000    0.073    0.002 subsampled_mh.py:599(reject)
#      7813    0.023    0.000    0.068    0.000 subsampled_mh.py:191(findBorder)
#    123402    0.049    0.000    0.049    0.000 subsampled_mh.py:30(isAAA)
#     92484    0.045    0.000    0.045    0.000 subsampled_mh.py:29(isAbsorbing)
#      7813    0.030    0.000    0.041    0.000 subsampled_mh.py:237(assignBorderSequnce)
#     15626    0.025    0.000    0.040    0.000 subsampled_mh.py:187(hasChildInAorD)
#      7813    0.027    0.000    0.035    0.000 subsampled_mh.py:202(computeRegenCounts)
#     23237    0.028    0.000    0.033    0.000 subsampled_mh.py:145(addAbsorbingNode)
#       101    0.002    0.000    0.033    0.000 subsampled_mh.py:525(sampleGlobalIndex)
#      7813    0.024    0.000    0.030    0.000 subsampled_mh.py:179(removeBrush)
#      7813    0.016    0.000    0.025    0.000 subsampled_mh.py:226(loadKernels)
#      7813    0.025    0.000    0.025    0.000 subsampled_mh.py:15(__init__)
#       101    0.002    0.000    0.019    0.000 subsampled_mh.py:51(constructScaffoldGlobalSection)
#     31188    0.015    0.000    0.015    0.000 subsampled_mh.py:31(hasLKernel)
#       101    0.001    0.000    0.006    0.000 subsampled_mh.py:91(extendCandidateScaffoldGlobalSection)
#      7813    0.003    0.000    0.003    0.000 subsampled_mh.py:227(<dictcomp>)
#       200    0.000    0.000    0.000    0.000 subsampled_mh.py:565(logDensityOfGlobalIndex)
#       101    0.000    0.000    0.000    0.000 subsampled_mh.py:517(__init__)
#       270    0.000    0.000    0.000    0.000 subsampled_mh.py:32(getLKernel)
#        65    0.000    0.000    0.000    0.000 subsampled_mh.py:598(accept)
# <pstats.Stats instance at 0x10a2ae7a0>

# %%
w_samples = []

# %%
v.infer('(subsampled_mh global_var 0 10 2 3 0.001 True .1)')
w_samples += [v.sample('w')]

# %%
w_samples
# Out:
# [[-0.6435581009546394,
#   0.23058955679505677,
#   0.016727522350037993,
#   -0.4278384701199536],
#  [-0.5429932465399678,
#   0.15928124984221698,
#   0.22428252862238374,
#   -0.32258235980223127],
#  [-0.529270358413875,
#   0.360322771362818,
#   0.2629283323575626,
#   -0.3705763052022004],
#  [-0.41316351871208074,
#   0.2983256470246335,
#   0.2941147322575855,
#   -0.260107546853128],
#  [-0.41171667859680683,
#   0.3223406857716346,
#   0.38237715874121,
#   -0.2831772799740596]]

# %% [markdown]
# ### Plot the scaffold

# %%
plt.figure(figsize=(20,20))
v.infer({'kernel': 'draw_scaffold', 'scope': 'global_var', 'block' : 0, 'transitions': 1})

# %%
plt.figure(figsize=(20,20))
v.infer({'kernel': 'draw_scaffold', 'scope': 'global_var', 'block' : 0, 'transitions': 1})

# %%
plt.figure(figsize=(20,20))
v.infer({'kernel': 'draw_scaffold', 'scope': 'global_var', 'block' : 0, 'transitions': 1})

# %%
plt.figure(figsize=(20,20))
v.infer({'kernel': 'draw_subsampled_scaffold', 'scope': 'global_var', 'block' : 0, 'transitions': 1, 'scope_to_subsample': 'to_subsample'})

# %% [markdown]
# ## VentureUnit

# %%
import ipdb
from venture import shortcuts
from venture.unit import VentureUnit
class BayesLogitRegress(VentureUnit):
    def makeAssumes(self):
        D = self.parameters['features']
        self.assume('D', D)
        self.assume('mu', '(zeros_array (+ D 1))')
        self.assume('Sigma', '(diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (+ D 1))))')
        self.assume('w', '(scope_include (quote global_var) 0 (multivariate_normal mu Sigma))')
        self.assume('f_x', '(lambda (x) (dot_product (cat_array (array 1) x) w))')
        self.assume('y_x', '(lambda (x) (bernoulli (/ 1 (+ 1 (exp (- 0 (f_x x)))))))')

    def makeObserves(self):
        N = self.parameters['observations']
        xs = self.parameters['xs']
        ys = self.parameters['ys']
        for n in xrange(N):
            self.observe('(scope_include (quote to_subsample) %d (y_x (array %s)))' \
                         % (n, ' '.join(['%f' % x for x in xs[n]])), ys[n])


# ripl = shortcuts.make_church_prime_ripl()
ripl = shortcuts.make_lite_church_prime_ripl()

D = 1
N = 30

w = np.random.normal(0, np.sqrt(0.1), D + 1).tolist()
xs = np.random.normal(0, 1, [N, D])
fs = xs.dot(w[1:]) + w[0]
ys = np.random.random(N) < 1 / (1 + np.exp(-fs))
xs = xs.tolist()
ys = ys.tolist()

print 'w: ', w
print 'fs: ', fs
print 'y: ', ys

parameters = {'features' : D, 'observations' : N, 'xs' : xs, 'ys' : ys}
# Out:
# w:  [-0.0737417091035467, 0.43532870639685833]
# fs:  [ 0.7422051  -0.24666909 -0.35633342 -1.14434153 -0.07048194  0.15947983
#  -0.37743306 -0.08851507 -0.07906823 -0.34342538  0.60565098 -0.23903462
#   0.04406719  0.57795023 -0.28538861  0.33426321 -0.1733061   0.08681821
#  -0.25100995  0.04289515  0.10067836 -0.36190028  0.44598382  0.32137449
#   0.12267638  0.13383811 -0.6034914   0.40764503  0.04548995  0.12855107]
# y:  [True, False, False, False, True, False, False, True, False, True, False, False, True, True, False, True, True, True, False, True, False, False, True, False, True, True, False, True, True, False]
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
model = BayesLogitRegress(ripl, parameters)
#history = model.runConditionedFromPrior(50, verbose=True)
#history = model.runFromJoint(50, verbose=True)
#history = model.sampleFromJoint(20, verbose=True)
# sample_hist, infer_hist, klHistory = model.computeJointKL(20, 10, verbose=True)
# klHistory.plot(fmt='png',directory='klHistory')
#history,_ = model.runFromConditional(100, verbose=True)
history,_ = model.runFromConditional(10, verbose=True, runs=1, infer='(mh global_var 0 3)')
history.plot(fmt='pdf',directory='figure_BayesLogitRegress_runFromConditional/')

#parameters = {'topics' : [4, 8], 'vocab' : 10, 'documents' : [8, 12], 'words_per_document' : [10, 100]}
#run_count = 0
#def runner(params):
#    print "Running setting " + str(run_count) + " of 8"
#    print params
#    return LDA(ripl, params).computeJointKL(20, 20, verbose=True)
#histories = productMap(parameters, runner)
#
#plotAsymptotics(parameters, histories, 'sweep_time', fmt='png', aggregate=True)

# %%
model = BayesLogitRegress(ripl, parameters)

# %%
history,_ = model.runFromConditional(30, verbose=True, runs=1, infer='(mh global_var 0 1)')
history,_ = model.runFromConditional(30, verbose=True, runs=1, infer='(mh global_var 0 1 true 0.1)')
history,_ = model.runFromConditional(30, verbose=True, runs=1, infer='(subsampled_mh global_var 0 1 w 1 3 0.001)')
history,_ = model.runFromConditional(30, verbose=True, runs=1, infer='(subsampled_mh global_var 0 1 w 1 3 0.001 true 0.1)')

# %%
history,_ = model.runFromConditional(200, verbose=True, runs=1, infer='(mh global_var 0 1 true 0.4)')
# Out:
# Starting run 0 of 1
# Running sweep 1 of 200
# Running sweep 2 of 200
# Running sweep 3 of 200
# Running sweep 4 of 200
# Running sweep 5 of 200
# Running sweep 6 of 200
# Running sweep 7 of 200
# Running sweep 8 of 200
# Running sweep 9 of 200
# Running sweep 10 of 200
# Running sweep 11 of 200
# Running sweep 12 of 200
# Running sweep 13 of 200
# Running sweep 14 of 200
# Running sweep 15 of 200
# Running sweep 16 of 200
# Running sweep 17 of 200
# Running sweep 18 of 200
# Running sweep 19 of 200
# Running sweep 20 of 200
# Running sweep 21 of 200
# Running sweep 22 of 200
# Running sweep 23 of 200
# Running sweep 24 of 200
# Running sweep 25 of 200
# Running sweep 26 of 200
# Running sweep 27 of 200
# Running sweep 28 of 200
# Running sweep 29 of 200
# Running sweep 30 of 200
# Running sweep 31 of 200
# Running sweep 32 of 200
# Running sweep 33 of 200
# Running sweep 34 of 200
# Running sweep 35 of 200
# Running sweep 36 of 200
# Running sweep 37 of 200
# Running sweep 38 of 200
# Running sweep 39 of 200
# Running sweep 40 of 200
# Running sweep 41 of 200
# Running sweep 42 of 200
# Running sweep 43 of 200
# Running sweep 44 of 200
# Running sweep 45 of 200
# Running sweep 46 of 200
# Running sweep 47 of 200
# Running sweep 48 of 200
# Running sweep 49 of 200
# Running sweep 50 of 200
# Running sweep 51 of 200
# Running sweep 52 of 200
# Running sweep 53 of 200
# Running sweep 54 of 200
# Running sweep 55 of 200
# Running sweep 56 of 200
# Running sweep 57 of 200
# Running sweep 58 of 200
# Running sweep 59 of 200
# Running sweep 60 of 200
# Running sweep 61 of 200
# Running sweep 62 of 200
# Running sweep 63 of 200
# Running sweep 64 of 200
# Running sweep 65 of 200
# Running sweep 66 of 200
# Running sweep 67 of 200
# Running sweep 68 of 200
# Running sweep 69 of 200
# Running sweep 70 of 200
# Running sweep 71 of 200
# Running sweep 72 of 200
# Running sweep 73 of 200
# Running sweep 74 of 200
# Running sweep 75 of 200
# Running sweep 76 of 200
# Running sweep 77 of 200
# Running sweep 78 of 200
# Running sweep 79 of 200
# Running sweep 80 of 200
# Running sweep 81 of 200
# Running sweep 82 of 200
# Running sweep 83 of 200
# Running sweep 84 of 200
# Running sweep 85 of 200
# Running sweep 86 of 200
# Running sweep 87 of 200
# Running sweep 88 of 200
# Running sweep 89 of 200
# Running sweep 90 of 200
# Running sweep 91 of 200
# Running sweep 92 of 200
# Running sweep 93 of 200
# Running sweep 94 of 200
# Running sweep 95 of 200
# Running sweep 96 of 200
# Running sweep 97 of 200
# Running sweep 98 of 200
# Running sweep 99 of 200
# Running sweep 100 of 200
# Running sweep 101 of 200
# Running sweep 102 of 200
# Running sweep 103 of 200
# Running sweep 104 of 200
# Running sweep 105 of 200
# Running sweep 106 of 200
# Running sweep 107 of 200
# Running sweep 108 of 200
# Running sweep 109 of 200
# Running sweep 110 of 200
# Running sweep 111 of 200
# Running sweep 112 of 200
# Running sweep 113 of 200
# Running sweep 114 of 200
# Running sweep 115 of 200
# Running sweep 116 of 200
# Running sweep 117 of 200
# Running sweep 118 of 200
# Running sweep 119 of 200
# Running sweep 120 of 200
# Running sweep 121 of 200
# Running sweep 122 of 200
# Running sweep 123 of 200
# Running sweep 124 of 200
# Running sweep 125 of 200
# Running sweep 126 of 200
# Running sweep 127 of 200
# Running sweep 128 of 200
# Running sweep 129 of 200
# Running sweep 130 of 200
# Running sweep 131 of 200
# Running sweep 132 of 200
# Running sweep 133 of 200
# Running sweep 134 of 200
# Running sweep 135 of 200
# Running sweep 136 of 200
# Running sweep 137 of 200
# Running sweep 138 of 200
# Running sweep 139 of 200
# Running sweep 140 of 200
# Running sweep 141 of 200
# Running sweep 142 of 200
# Running sweep 143 of 200
# Running sweep 144 of 200
# Running sweep 145 of 200
# Running sweep 146 of 200
# Running sweep 147 of 200
# Running sweep 148 of 200
# Running sweep 149 of 200
# Running sweep 150 of 200
# Running sweep 151 of 200
# Running sweep 152 of 200
# Running sweep 153 of 200
# Running sweep 154 of 200
# Running sweep 155 of 200
# Running sweep 156 of 200
# Running sweep 157 of 200
# Running sweep 158 of 200
# Running sweep 159 of 200
# Running sweep 160 of 200
# Running sweep 161 of 200
# Running sweep 162 of 200
# Running sweep 163 of 200
# Running sweep 164 of 200
# Running sweep 165 of 200
# Running sweep 166 of 200
# Running sweep 167 of 200
# Running sweep 168 of 200
# Running sweep 169 of 200
# Running sweep 170 of 200
# Running sweep 171 of 200
# Running sweep 172 of 200
# Running sweep 173 of 200
# Running sweep 174 of 200
# Running sweep 175 of 200
# Running sweep 176 of 200
# Running sweep 177 of 200
# Running sweep 178 of 200
# Running sweep 179 of 200
# Running sweep 180 of 200
# Running sweep 181 of 200
# Running sweep 182 of 200
# Running sweep 183 of 200
# Running sweep 184 of 200
# Running sweep 185 of 200
# Running sweep 186 of 200
# Running sweep 187 of 200
# Running sweep 188 of 200
# Running sweep 189 of 200
# Running sweep 190 of 200
# Running sweep 191 of 200
# Running sweep 192 of 200
# Running sweep 193 of 200
# Running sweep 194 of 200
# Running sweep 195 of 200
# Running sweep 196 of 200
# Running sweep 197 of 200
# Running sweep 198 of 200
# Running sweep 199 of 200
# Running sweep 200 of 200

# %%
for i in range(len(history.nameToSeries['w'])):
    plot([v[0] for v in history.nameToSeries['w'][i].values])
    plot([v[1] for v in history.nameToSeries['w'][i].values])

# %%
for i in range(len(history.nameToSeries['w'])):
    plot([v[0] for v in history.nameToSeries['w'][i].values])
    plot([v[1] for v in history.nameToSeries['w'][i].values])

# %%
for i in range(len(history.nameToSeries['w'])):
    plot([v[0] for v in history.nameToSeries['w'][i].values])
    plot([v[1] for v in history.nameToSeries['w'][i].values])

# %%
history,_ = model.runFromConditional(200, verbose=True, runs=1, infer='(subsampled_mh global_var 0 1 1 3 0.001 true 0.4)')
# Out:
# Starting run 0 of 1
# Running sweep 1 of 200
# Running sweep 2 of 200
# Running sweep 3 of 200
# Running sweep 4 of 200
# Running sweep 5 of 200
# Running sweep 6 of 200
# Running sweep 7 of 200
# Running sweep 8 of 200
# Running sweep 9 of 200
# Running sweep 10 of 200
# Running sweep 11 of 200
# Running sweep 12 of 200
# Running sweep 13 of 200
# Running sweep 14 of 200
# Running sweep 15 of 200
# Running sweep 16 of 200
# Running sweep 17 of 200
# Running sweep 18 of 200
# Running sweep 19 of 200
# Running sweep 20 of 200
# Running sweep 21 of 200
# Running sweep 22 of 200
# Running sweep 23 of 200
# Running sweep 24 of 200
# Running sweep 25 of 200
# Running sweep 26 of 200
# Running sweep 27 of 200
# Running sweep 28 of 200
# Running sweep 29 of 200
# Running sweep 30 of 200
# Running sweep 31 of 200
# Running sweep 32 of 200
# Running sweep 33 of 200
# Running sweep 34 of 200
# Running sweep 35 of 200
# Running sweep 36 of 200
# Running sweep 37 of 200
# Running sweep 38 of 200
# Running sweep 39 of 200
# Running sweep 40 of 200
# Running sweep 41 of 200
# Running sweep 42 of 200
# Running sweep 43 of 200
# Running sweep 44 of 200
# Running sweep 45 of 200
# Running sweep 46 of 200
# Running sweep 47 of 200
# Running sweep 48 of 200
# Running sweep 49 of 200
# Running sweep 50 of 200
# Running sweep 51 of 200
# Running sweep 52 of 200
# Running sweep 53 of 200
# Running sweep 54 of 200
# Running sweep 55 of 200
# Running sweep 56 of 200
# Running sweep 57 of 200
# Running sweep 58 of 200
# Running sweep 59 of 200
# Running sweep 60 of 200
# Running sweep 61 of 200
# Running sweep 62 of 200
# Running sweep 63 of 200
# Running sweep 64 of 200
# Running sweep 65 of 200
# Running sweep 66 of 200
# Running sweep 67 of 200
# Running sweep 68 of 200
# Running sweep 69 of 200
# Running sweep 70 of 200
# Running sweep 71 of 200
# Running sweep 72 of 200
# Running sweep 73 of 200
# Running sweep 74 of 200
# Running sweep 75 of 200
# Running sweep 76 of 200
# Running sweep 77 of 200
# Running sweep 78 of 200
# Running sweep 79 of 200
# Running sweep 80 of 200
# Running sweep 81 of 200
# Running sweep 82 of 200
# Running sweep 83 of 200
# Running sweep 84 of 200
# Running sweep 85 of 200
# Running sweep 86 of 200
# Running sweep 87 of 200
# Running sweep 88 of 200
# Running sweep 89 of 200
# Running sweep 90 of 200
# Running sweep 91 of 200
# Running sweep 92 of 200
# Running sweep 93 of 200
# Running sweep 94 of 200
# Running sweep 95 of 200
# Running sweep 96 of 200
# Running sweep 97 of 200
# Running sweep 98 of 200
# Running sweep 99 of 200
# Running sweep 100 of 200
# Running sweep 101 of 200
# Running sweep 102 of 200
# Running sweep 103 of 200
# Running sweep 104 of 200
# Running sweep 105 of 200
# Running sweep 106 of 200
# Running sweep 107 of 200
# Running sweep 108 of 200
# Running sweep 109 of 200
# Running sweep 110 of 200
# Running sweep 111 of 200
# Running sweep 112 of 200
# Running sweep 113 of 200
# Running sweep 114 of 200
# Running sweep 115 of 200
# Running sweep 116 of 200
# Running sweep 117 of 200
# Running sweep 118 of 200
# Running sweep 119 of 200
# Running sweep 120 of 200
# Running sweep 121 of 200
# Running sweep 122 of 200
# Running sweep 123 of 200
# Running sweep 124 of 200
# Running sweep 125 of 200
# Running sweep 126 of 200
# Running sweep 127 of 200
# Running sweep 128 of 200
# Running sweep 129 of 200
# Running sweep 130 of 200
# Running sweep 131 of 200
# Running sweep 132 of 200
# Running sweep 133 of 200
# Running sweep 134 of 200
# Running sweep 135 of 200
# Running sweep 136 of 200
# Running sweep 137 of 200
# Running sweep 138 of 200
# Running sweep 139 of 200
# Running sweep 140 of 200
# Running sweep 141 of 200
# Running sweep 142 of 200
# Running sweep 143 of 200
# Running sweep 144 of 200
# Running sweep 145 of 200
# Running sweep 146 of 200
# Running sweep 147 of 200
# Running sweep 148 of 200
# Running sweep 149 of 200
# Running sweep 150 of 200
# Running sweep 151 of 200
# Running sweep 152 of 200
# Running sweep 153 of 200
# Running sweep 154 of 200
# Running sweep 155 of 200
# Running sweep 156 of 200
# Running sweep 157 of 200
# Running sweep 158 of 200
# Running sweep 159 of 200
# Running sweep 160 of 200
# Running sweep 161 of 200
# Running sweep 162 of 200
# Running sweep 163 of 200
# Running sweep 164 of 200
# Running sweep 165 of 200
# Running sweep 166 of 200
# Running sweep 167 of 200
# Running sweep 168 of 200
# Running sweep 169 of 200
# Running sweep 170 of 200
# Running sweep 171 of 200
# Running sweep 172 of 200
# Running sweep 173 of 200
# Running sweep 174 of 200
# Running sweep 175 of 200
# Running sweep 176 of 200
# Running sweep 177 of 200
# Running sweep 178 of 200
# Running sweep 179 of 200
# Running sweep 180 of 200
# Running sweep 181 of 200
# Running sweep 182 of 200
# Running sweep 183 of 200
# Running sweep 184 of 200
# Running sweep 185 of 200
# Running sweep 186 of 200
# Running sweep 187 of 200
# Running sweep 188 of 200
# Running sweep 189 of 200
# Running sweep 190 of 200
# Running sweep 191 of 200
# Running sweep 192 of 200
# Running sweep 193 of 200
# Running sweep 194 of 200
# Running sweep 195 of 200
# Running sweep 196 of 200
# Running sweep 197 of 200
# Running sweep 198 of 200
# Running sweep 199 of 200
# Running sweep 200 of 200

# %%
for i in range(len(history.nameToSeries['w'])):
    plot([v[0] for v in history.nameToSeries['w'][i].values])
    plot([v[1] for v in history.nameToSeries['w'][i].values])
