# %% [markdown]
# # Subsampled MH for Joint DP Mixture of Logistic Regression Experts

# %%
import numpy as np
import ipdb
from venture.venturemagics.ip_parallel import *
from venture.unit import Analytics
make_ripl = mk_l_ripl

# %%
v = make_ripl()

# %% [markdown]
# #### Parameters

# %%
D = 2
N = 10
w = np.random.normal(0, np.sqrt(0.1), D + 1).tolist()
X = np.random.normal(0, 1, [N, D])
f = X.dot(w[1:]) + w[0]
y = np.random.random(N) < 1 / (1 + np.exp(-f))
X = X.tolist()
y = y.tolist()

# %%
# Hyper-param for w
Sigma_w = np.sqrt(0.1)
# Hyper-param for the conjugate prior of mu_x
m0 = np.zeros(D) # \mu_0
k0 = 10 # m
# Hyper-param for the conjugate prior of Sigma_x
v0 = 10 # n_0
S0 = np.eye(D) * v0 # Psi

# %%
# %%venture v
# [clear]
# [assume D 2]
# [assume mu_w (zeros_array (+ D 1))]
# [assume Sigma_w (diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (+ D 1))))]
# [assume m0 (zeros_array D)]
# [assume k0 10]
# [assume v0 10]
# [assume S0 (diagonal_matrix (scalar_product v0 (ones_array D)))]
# [assume alpha (scope_include (quote alpha) 0 (uniform_continuous .5 1))]
# [assume crp (make_crp alpha)]
# [assume z (mem (lambda (i) (scope_include (quote z) i (crp))))]
# [assume w (mem (lambda (z) (scope_include (quote w) z (multivariate_normal mu_w Sigma_w))))]
# [assume cmvn (mem (lambda (z) (make_cmvn m0 k0 v0 S0)))]
# [assume x (mem (lambda (i) (scope_include (quote x) i ((scope_exclude (quote x) (cmvn (z i)))))))]
# [assume y (lambda (i) (scope_include (quote y) i (bernoulli (scope_exclude (quote y) (linear_logistic (w (z i)) (x i))))))]

# %%
for n in xrange(N):
    v.observe('(x %d)' % n, \
              {'type': 'list', 'value': [{'type': 'real', 'value': 1}, {'type': 'real', 'value': 2}]})
    v.observe('(y %d)' % n, ys[n])

# %%
# %%venture v
# [clear]
# [assume D 2]
# [assume mu_w (zeros_array (+ D 1))]
# [assume Sigma_w (diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (+ D 1))))]
# [assume m0 (zeros_array D)]
# [assume k0 10]
# [assume v0 10]
# [assume S0 (diagonal_matrix (scalar_product v0 (ones_array D)))]
# [assume alpha (scope_include (quote alpha) 0 (uniform_continuous .5 1))]
# [assume crp (make_crp alpha)]
# [assume z (mem (lambda (i) (scope_include (quote z) i (crp))))]
# [assume w (mem (lambda (z) (scope_include (quote w) z (multivariate_normal mu_w Sigma_w))))]
# [assume cmvn (mem (lambda (z) (make_cmvn m0 k0 v0 S0)))]
# [assume x (lambda (i) (cmvn (z i)))]
# [assume y (lambda (i x) (bernoulli (linear_logistic (w (z i)) x)))]

# %%
for n in xrange(N):
    v.observe('(x %d)' % n, \
              {'type': 'list', 'value': [{'type': 'real', 'value': x} for x in X[n]]})
    v.observe('(y %d (array %s))' % (n, ' '.join(repr(x) for x in X[n])), y[n])

# %%
for d in v.list_directives():
    print directive_to_string(d)
# Out:
# [assume D 2.0]
# [assume mu_w (zeros_array (add D 1.0))]
# [assume Sigma_w (diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (add D 1.0))))]
# [assume m0 (zeros_array D)]
# [assume k0 10.0]
# [assume v0 10.0]
# [assume S0 (diagonal_matrix (scalar_product v0 (ones_array D)))]
# [assume alpha (scope_include (quote alpha) 0.0 (uniform_continuous 0.5 1.0))]
# [assume crp (make_crp alpha)]
# [assume z (mem (lambda (i) (scope_include (quote z) i (crp))))]
# [assume w (mem (lambda (z) (scope_include (quote w) z (multivariate_normal mu_w Sigma_w))))]
# [assume cmvn (mem (lambda (z) (make_cmvn m0 k0 v0 S0)))]
# [assume x (lambda (i) (cmvn (z i)))]
# [assume y (lambda (i x) (bernoulli (linear_logistic (w (z i)) x)))]
# [observe (x 0.0) [0.0798995249031958, 0.36370317809344055]]
# [observe (y 0.0 (array 0.0798995249032 0.363703178093)) True]
# [observe (x 1.0) [-0.2989275255138235, 0.20821633187814556]]
# [observe (y 1.0 (array -0.298927525514 0.208216331878)) True]
# [observe (x 2.0) [-0.2350452732794406, -0.4485798997973138]]
# [observe (y 2.0 (array -0.235045273279 -0.448579899797)) True]
# [observe (x 3.0) [-1.5276303276886196, 1.1068534344696133]]
# [observe (y 3.0 (array -1.52763032769 1.10685343447)) True]
# [observe (x 4.0) [1.9818534929825498, -0.41026797646795243]]
# [observe (y 4.0 (array 1.98185349298 -0.410267976468)) True]
# [observe (x 5.0) [0.673154267220336, 0.840540603551295]]
# [observe (y 5.0 (array 0.67315426722 0.840540603551)) True]
# [observe (x 6.0) [-0.26312288983586335, -0.8074235713206254]]
# [observe (y 6.0 (array -0.263122889836 -0.807423571321)) True]
# [observe (x 7.0) [0.833231309574156, 1.4538172862321905]]
# [observe (y 7.0 (array 0.833231309574 1.45381728623)) True]
# [observe (x 8.0) [1.102955532887204, 2.6929095300409704]]
# [observe (y 8.0 (array 1.10295553289 2.69290953004)) True]
# [observe (x 9.0) [1.708668198763543, 0.9782314057885744]]
# [observe (y 9.0 (array 1.70866819876 0.978231405789)) True]

# %%
zs = [v.sample('(z %d)' % i) for i in range(N)]
print "zs:", zs
trace = v.sivm.core_sivm.engine.traces[0]
for scope in trace.scopes.keys():
    print scope, len(trace.getAllNodesInScope(scope))
# Out:
# zs: [1, 1, 1, 1, 1, 1, 1, 2, 1, 3]
# default 24
# alpha 1
# z 10
# w 3

# %%
for z in range(1,max(zs) + 1): 
    print v.sample('(w %d)' % z)
# Out:
# [-0.29623382319549596, -1.8305749102530386, 0.11579365073237358]
# [0.8210606937906627, 1.1397440955168427, 0.06716111784203338]
# [0.9575365841535657, -0.6932673818053346, -0.25604643517997494]

# %%
xt = zip(*[xs[i] for i in range(len(xs)) if ys[i]])
plot(xt[0], xt[1], 'gx')
xt = zip(*[xs[i] for i in range(len(xs)) if not ys[i]])
plot(xt[0], xt[1], 'rx')

# %%
v.infer('(mh default all 1)')

# %% [markdown]
# ### Plot the scaffold

# %%
plt.figure(figsize=(80,80))
v.infer({'kernel': 'draw_scaffold', 'scope': 'default', 'block' : 'all', 'transitions': 1})
print 'Scaffold of default'
plt.savefig('/Users/yutian/Desktop/scaffold_jointdplr_scope_default.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-201-1a08a91a8892> in <module>()
#       1 plt.figure(figsize=(80,80))
# ----> 2 v.infer({'kernel': 'draw_scaffold', 'scope': 'default', 'block' : 'all', 'transitions': 1})
#       3 print 'Scaffold of default'
#       4 plt.savefig('/Users/yutian/Desktop/scaffold_jointdplr_scope_default.pdf')
#
# /usr/local/lib/python2.7/site-packages/venture/ripl/ripl.pyc in infer(self, params)
#     405
#     406     def infer(self, params=None):
# --> 407         self.execute_instruction({'instruction':'infer', 'params': self.parseInferParams(params)})
#     408
#     409     def clear(self):
#
# /usr/local/lib/python2.7/site-packages/venture/ripl/ripl.pyc in execute_instruction(self, instruction, params)
#      73             stringable_instruction = parsed_instruction # Will be unparsed on use
#      74         try: # execute instruction, and handle possible exception
# ---> 75             ret_value = self.sivm.execute_instruction(parsed_instruction)
#      76         except VentureException as e:
#      77             self._raise_annotated_error(e, stringable_instruction)
#
# /usr/local/lib/python2.7/site-packages/venture/sivm/venture_sivm.pyc in execute_instruction(self, instruction)
#      61                 f = getattr(self,'_do_'+instruction_type)
#      62                 return f(instruction)
# ---> 63             response = self._call_core_sivm_instruction(instruction)
#      64             return response
#      65
#
# /usr/local/lib/python2.7/site-packages/venture/sivm/venture_sivm.pyc in _call_core_sivm_instruction(self, instruction)
#     122             desugared_src_location['expression_index'] = new_index
#     123         try:
# --> 124             response = self.core_sivm.execute_instruction(desugared_instruction)
#     125         except VentureException as e:
#     126             if e.exception == "evaluation":
#
# /usr/local/lib/python2.7/site-packages/venture/sivm/core_sivm.pyc in execute_instruction(self, instruction)
#      42         utils.validate_instruction(instruction,self._implemented_instructions)
#      43         f = getattr(self,'_do_'+instruction['instruction'])
# ---> 44         return f(instruction)
#      45
#      46     ###############################
#
# /usr/local/lib/python2.7/site-packages/venture/sivm/core_sivm.pyc in _do_infer(self, instruction)
#     142                 utils.validate_dict)
#     143         # TODO FIXME figure out how to validate the arguments
# --> 144         val = self.engine.infer(d)
#     145         return {}
#     146
#
# /usr/local/lib/python2.7/site-packages/venture/engine/engine.pyc in infer(self, params)
#     162     self.set_default_params(params)
#     163
# --> 164     self.incorporate()
#     165     if 'command' in params and params['command'] == "resample":
#     166       P = params['particles']
#
# /usr/local/lib/python2.7/site-packages/venture/engine/engine.pyc in incorporate(self)
#     155   def incorporate(self):
#     156     for i,trace in enumerate(self.traces):
# --> 157       self.weights[i] += trace.makeConsistent()
#     158
#     159   def infer(self,params=None):
#
# /usr/local/lib/python2.7/site-packages/venture/lite/trace.pyc in makeConsistent(self)
#     302 #      print "PROPAGATE",node,appNode
#     303       scaffold = constructScaffold(self,[set([appNode])])
# --> 304       rhoWeight,_ = detachAndExtract(self,scaffold.border[0],scaffold)
#     305       assertTorus(scaffold)
#     306       scaffold.lkernels[appNode] = DeterministicLKernel(self.pspAt(appNode),val)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/detach.pyc in detachAndExtract(trace, border, scaffold, compute_gradient)
#      19     else:
#      20       if node.isObservation: weight += unconstrain(trace,trace.getOutermostNonReferenceApplication(node))
# ---> 21       weight += extract(trace,node,scaffold,omegaDB, compute_gradient)
#      22   return weight,omegaDB
#      23
#
# /usr/local/lib/python2.7/site-packages/venture/lite/detach.pyc in extract(trace, node, scaffold, omegaDB, compute_gradient)
#      70         if isinstance(node,RequestNode):
#      71           weight += unevalRequests(trace, node, scaffold, omegaDB, compute_gradient)
# ---> 72         weight += unapplyPSP(trace, node, scaffold, omegaDB, compute_gradient)
#      73       else:
#      74         trace.setValueAt(node,None)
#
# /usr/local/lib/python2.7/site-packages/venture/lite/detach.pyc in unapplyPSP(trace, node, scaffold, omegaDB, compute_gradient)
#     131   psp.unincorporate(trace.valueAt(node),args)
#     132   if scaffold.hasLKernel(node):
# --> 133     weight += scaffold.getLKernel(node).reverseWeight(trace,trace.valueAt(node),args)
#     134     if compute_gradient:
#     135       # TODO Should this take the whole args?  Should it take the esr parents into account?
#
# /usr/local/lib/python2.7/site-packages/venture/lite/psp.pyc in reverseWeight(self, trace, oldValue, args)
#     356     return self.kernel.reverseWeight(trace,
#     357                                      self.f_type.unwrap_return(oldValue),
# --> 358                                      self.f_type.unwrap_args(args))
#     359
#     360   def weightBound(self, trace, newValue, oldValue, args):
#
# /usr/local/lib/python2.7/site-packages/venture/lite/lkernel.pyc in reverseWeight(self, trace, oldValue, args)
#      14   def weight(self, _trace, _newValue, _oldValue, _args): return 0
#      15   def reverseWeight(self,trace,oldValue,args):
# ---> 16     return self.weight(trace,oldValue,None,args)
#      17   def gradientOfReverseWeight(self, _trace, _value, args): return (0, [0 for _ in args.operandValues])
#      18   def weightBound(self, _trace, _newValue, _oldValue, _args):
#
# /usr/local/lib/python2.7/site-packages/venture/lite/lkernel.pyc in weight(self, _trace, newValue, _oldValue, args)
#      27   def weight(self,_trace,newValue,_oldValue,args):
#      28     assert isinstance(newValue,VentureSP)
# ---> 29     return newValue.outputPSP.logDensityOfCounts(args.madeSPAux)
#      30   def weightBound(self, _trace, _newValue, _oldValue, args):
#      31     # Going through the maker here because the new value is liable to
#
# /usr/local/lib/python2.7/site-packages/venture/lite/psp.pyc in logDensityOfCounts(self, aux)
#     338   # TODO Is this method part of the psp interface?
#     339   def logDensityOfCounts(self,aux):
# --> 340     return self.psp.logDensityOfCounts(aux)
#     341
#     342 class TypedLKernel(LKernel):
#
# /usr/local/lib/python2.7/site-packages/venture/lite/cmvn.pyc in logDensityOfCounts(self, aux)
#     131     (mN,kN,vN,SN) = self.updatedParams(aux)
#     132     term1 = - (aux.N * self.d * math.log(math.pi)) / 2
# --> 133     term2 = logGenGamma(self.d,float(vN) / 2)
#     134     term3 = - logGenGamma(self.d,float(self.v0) / 2)
#     135     term4 = (float(self.v0) / 2) * np.linalg.slogdet(self.S0)[1] # first is sign
#
# NameError: global name 'logGenGamma' is not defined

# %%
debug
# Out:
# > /usr/local/lib/python2.7/site-packages/venture/lite/cmvn.py(133)logDensityOfCounts()
#     132     term1 = - (aux.N * self.d * math.log(math.pi)) / 2
# --> 133     term2 = logGenGamma(self.d,float(vN) / 2)
#     134     term3 = - logGenGamma(self.d,float(self.v0) / 2)
# ipdb> up
# > /usr/local/lib/python2.7/site-packages/venture/lite/psp.py(340)logDensityOfCounts()
#     339   def logDensityOfCounts(self,aux):
# --> 340     return self.psp.logDensityOfCounts(aux)
#     341
# ipdb> up
# > /usr/local/lib/python2.7/site-packages/venture/lite/lkernel.py(29)weight()
#      28     assert isinstance(newValue,VentureSP)
# ---> 29     return newValue.outputPSP.logDensityOfCounts(args.madeSPAux)
#      30   def weightBound(self, _trace, _newValue, _oldValue, args):
# ipdb> up
# > /usr/local/lib/python2.7/site-packages/venture/lite/lkernel.py(16)reverseWeight()
#      15   def reverseWeight(self,trace,oldValue,args):
# ---> 16     return self.weight(trace,oldValue,None,args)
#      17   def gradientOfReverseWeight(self, _trace, _value, args): return (0, [0 for _ in args.operandValues])
# ipdb> up
# > /usr/local/lib/python2.7/site-packages/venture/lite/psp.py(358)reverseWeight()
#     357                                      self.f_type.unwrap_return(oldValue),
# --> 358                                      self.f_type.unwrap_args(args))
#     359
# ipdb> up
# > /usr/local/lib/python2.7/site-packages/venture/lite/detach.py(133)unapplyPSP()
#     132   if scaffold.hasLKernel(node):
# --> 133     weight += scaffold.getLKernel(node).reverseWeight(trace,trace.valueAt(node),args)
#     134     if compute_gradient:
# ipdb> up
# > /usr/local/lib/python2.7/site-packages/venture/lite/detach.py(72)extract()
#      71           weight += unevalRequests(trace, node, scaffold, omegaDB, compute_gradient)
# ---> 72         weight += unapplyPSP(trace, node, scaffold, omegaDB, compute_gradient)
#      73       else:
# ipdb> up
# > /usr/local/lib/python2.7/site-packages/venture/lite/detach.py(21)detachAndExtract()
#      20       if node.isObservation: weight += unconstrain(trace,trace.getOutermostNonReferenceApplication(node))
# ---> 21       weight += extract(trace,node,scaffold,omegaDB, compute_gradient)
#      22   return weight,omegaDB
# ipdb> up
# > /usr/local/lib/python2.7/site-packages/venture/lite/trace.py(304)makeConsistent()
#     303       scaffold = constructScaffold(self,[set([appNode])])
# --> 304       rhoWeight,_ = detachAndExtract(self,scaffold.border[0],scaffold)
#     305       assertTorus(scaffold)
# ipdb> appNode
# <venture.lite.node.OutputNode object at 0x10f47e6d0>
# ipdb> appNode.value
# <venture.lite.cmvn.CMVNSP object at 0x10f3411d0>
# ipdb> self.unpropagatedObservations
# {<venture.lite.node.OutputNode object at 0x10f4cb410>: VentureArray([VentureNumber(0.0798995249032), VentureNumber(0.363703178093)]), <venture.lite.node.OutputNode object at 0x11208d3d0>: VentureNumber(1.0), <venture.lite.node.OutputNode object at 0x112048850>: VentureNumber(1.0), <venture.lite.node.OutputNode object at 0x10f2ee590>: VentureNumber(1.0), <venture.lite.node.OutputNode object at 0x10f277410>: VentureArray([VentureNumber(0.833231309574), VentureNumber(1.45381728623)]), <venture.lite.node.OutputNode object at 0x10f4dbc90>: VentureArray([VentureNumber(-0.235045273279), VentureNumber(-0.448579899797)]), <venture.lite.node.OutputNode object at 0x111dcec90>: VentureArray([VentureNumber(1.70866819876), VentureNumber(0.978231405789)]), <venture.lite.node.OutputNode object at 0x111dcee90>: VentureNumber(1.0), <venture.lite.node.OutputNode object at 0x10f31e8d0>: VentureNumber(1.0), <venture.lite.node.OutputNode object at 0x110dec0d0>: VentureArray([VentureNumber(-0.298927525514), VentureNumber(0.208216331878)]), <venture.lite.node.OutputNode object at 0x10f320110>: VentureArray([VentureNumber(1.98185349298), VentureNumber(-0.410267976468)]), <venture.lite.node.OutputNode object at 0x10f404dd0>: VentureNumber(1.0), <venture.lite.node.OutputNode object at 0x111df8fd0>: VentureArray([VentureNumber(-1.52763032769), VentureNumber(1.10685343447)]), <venture.lite.node.OutputNode object at 0x111da11d0>: VentureNumber(1.0), <venture.lite.node.OutputNode object at 0x10f404550>: VentureArray([VentureNumber(-0.263122889836), VentureNumber(-0.807423571321)]), <venture.lite.node.OutputNode object at 0x1127d5b10>: VentureArray([VentureNumber(1.10295553289), VentureNumber(2.69290953004)]), <venture.lite.node.OutputNode object at 0x112048490>: VentureArray([VentureNumber(0.67315426722), VentureNumber(0.840540603551)]), <venture.lite.node.OutputNode object at 0x1127b6790>: VentureNumber(1.0), <venture.lite.node.OutputNode object at 0x10f4cf5d0>: VentureNumber(1.0), <venture.lite.node.OutputNode object at 0x112081e50>: VentureNumber(1.0)}
# ipdb> q

# %%
plt.figure(figsize=(55,55))
v.infer({'kernel': 'draw_scaffold', 'scope': 'w', 'block' : 'all', 'transitions': 1})
print 'Scaffold of w 1'
plt.savefig('/Users/yutian/Desktop/scaffold_jointdplr_scope_w_1.png')
# Out:
# Scaffold of w 1

# %%
plt.figure(figsize=(35,35))
v.infer({'kernel': 'draw_scaffold', 'scope': 'scope_z', 'block' : 'all', 'transitions': 1})
print 'Scaffold of z'
plt.savefig('/Users/yutian/Desktop/scaffold_dpmlr_scope_z.pdf')
# Out:
# Scaffold of z

# %%
plt.figure(figsize=(35,35))
v.infer({'kernel': 'draw_scaffold', 'scope': 'scope_alpha', 'block' : 'all', 'transitions': 1})
print 'Scaffold of alpha'
plt.savefig('/Users/yutian/Desktop/scaffold_dpmlr_scope_alpha.pdf')
# Out:
# Scaffold of alpha

# %%
plt.figure(figsize=(35,35))
v.infer({'kernel': 'draw_scaffold', 'scope': 'scope_y', 'block' : 'all', 'transitions': 1})
print 'Scaffold of y'
plt.savefig('/Users/yutian/Desktop/scaffold_dpmlr_scope_y.pdf')
# Out:
# Scaffold of y

# %%
plt.figure(figsize=(20,20))
v.infer({'kernel': 'draw_subsampled_scaffold', 'scope': 'global_var', 'block' : 0, 'transitions': 1, 'scope_to_subsample': 'to_subsample'})

# %% [markdown]
# ## VentureUnit

# %%
import ipdb
from venture import shortcuts
from venture.unit import VentureUnit
class DPMBayesLogitRegress(VentureUnit):
    def makeAssumes(self):
        D = self.parameters['features']
        self.assume('D', D)
        self.assume('mu', '(zeros_array (+ D 1))')
        self.assume('Sigma', '(diagonal_matrix (scalar_product (sqrt 0.1) (ones_array (+ D 1))))')
        self.assume('alpha', '(scope_include (quote scope_alpha) 0 (uniform_continuous .5 1))')
        self.assume('crp', '(make_crp alpha)')
        self.assume('z', '(mem (lambda (i) (scope_include (quote scope_z) i (crp))))')
        self.assume('w', '(mem (lambda (z) (scope_include (quote scope_w) z (multivariate_normal mu Sigma))))')
        self.assume('f_x', '(lambda (x i) (dot_product (cat_array (array 1) x) (w (z i))))')
        self.assume('y_x', '(lambda (x i) (scope_include (quote scope_y) i (bernoulli (/ 1 (+ 1 (exp (- 0 (f_x x i))))))))')
        
    def makeObserves(self):
        N = self.parameters['observations']
        xs = self.parameters['xs']
        ys = self.parameters['ys']
        for n in xrange(N):
            self.observe('(y_x (array %s) %d)' % (' '.join(['%f' % x for x in xs[n]]), n), ys[n])

# ripl = shortcuts.make_church_prime_ripl()
ripl = shortcuts.make_lite_church_prime_ripl()

D = 2
N = 10
w = np.random.normal(0, np.sqrt(0.1), D + 1).tolist()
xs = np.random.normal(0, 1, [N, D])
fs = xs.dot(w[1:]) + w[0]
ys = np.random.random(N) < 1 / (1 + np.exp(-fs))
xs = xs.tolist()
ys = ys.tolist()

print 'w: ', w
print 'y: ', ys

parameters = {'features' : D, 'observations' : N, 'xs' : xs, 'ys' : ys}
# Out:
# w:  [0.1675958756482819, 0.09026870921713752, -0.06923130466275353]
# y:  [True, False, True, False, True, True, True, False, True, False]
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
model = DPMBayesLogitRegress(ripl, parameters)
#history = model.runConditionedFromPrior(50, verbose=True)
#history = model.runFromJoint(50, verbose=True)
#history = model.sampleFromJoint(20, verbose=True)
# sample_hist, infer_hist, klHistory = model.computeJointKL(20, 10, verbose=True)
# klHistory.plot(fmt='png',directory='klHistory')
#history,_ = model.runFromConditional(100, verbose=True)
history,_ = model.runFromConditional(10, verbose=True, runs=1, infer='(mh global_var 0 3)')
history.plot(fmt='pdf',directory='figure_BayesLogitRegress_runFromConditional/')

#parameters = {'topics' : [4, 8], 'vocab' : 10, 'documents' : [8, 12], 'words_per_document' : [10, 100]}
#run_count = 0
#def runner(params):
#    print "Running setting " + str(run_count) + " of 8"
#    print params
#    return LDA(ripl, params).computeJointKL(20, 20, verbose=True)
#histories = productMap(parameters, runner)
#
#plotAsymptotics(parameters, histories, 'sweep_time', fmt='png', aggregate=True)

# %%
model = DPMBayesLogitRegress(ripl, parameters)

# %%
history,_ = model.runFromConditional(5, verbose=True, runs=1, infer='(mh scope_w 1 1)')
# Out:
# Starting run 0 of 1
# Running sweep 1 of 5
# Running sweep 2 of 5
# Running sweep 3 of 5
# Running sweep 4 of 5
# Running sweep 5 of 5

# %%
for i in range(len(history.nameToSeries['w'])):
    plot([v[0] for v in history.nameToSeries['w'][i].values])
    plot([v[1] for v in history.nameToSeries['w'][i].values])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-9690e584d8aa> in <module>()
#       1 for i in range(len(history.nameToSeries['w'])):
# ----> 2     plot([v[0] for v in history.nameToSeries['w'][i].values])
#       3     plot([v[1] for v in history.nameToSeries['w'][i].values])
#
# /usr/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2985         ax.hold(hold)
#    2986     try:
# -> 2987         ret = ax.plot(*args, **kwargs)
#    2988         draw_if_interactive()
#    2989     finally:
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4136
#    4137         for line in self._get_lines(*args, **kwargs):
# -> 4138             self.add_line(line)
#    4139             lines.append(line)
#    4140
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes.pyc in add_line(self, line)
#    1495             line.set_clip_path(self.patch)
#    1496
# -> 1497         self._update_line_limits(line)
#    1498         if not line.get_label():
#    1499             line.set_label('_line%d' % len(self.lines))
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes.pyc in _update_line_limits(self, line)
#    1506         Figures out the data limit of the given line, updating self.dataLim.
#    1507         """
# -> 1508         path = line.get_path()
#    1509         if path.vertices.size == 0:
#    1510             return
#
# /usr/local/lib/python2.7/site-packages/matplotlib/lines.pyc in get_path(self)
#     741         """
#     742         if self._invalidy or self._invalidx:
# --> 743             self.recache()
#     744         return self._path
#     745
#
# /usr/local/lib/python2.7/site-packages/matplotlib/lines.pyc in recache(self, always)
#     427                 y = ma.asarray(yconv, np.float_)
#     428             else:
# --> 429                 y = np.asarray(yconv, np.float_)
#     430             y = y.ravel()
#     431         else:
#
# /usr/local/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     458
#     459     """
# --> 460     return array(a, dtype, copy=False, order=order)
#     461
#     462 def asanyarray(a, dtype=None, order=None):
#
# ValueError: could not convert string to float: u

# %%
history,_ = model.runFromConditional(20, verbose=True, runs=1, infer='(subsampled_mh scope_w 1 1 1 3 .01)')
# Out:
# Starting run 0 of 1
# Running sweep 1 of 20
# Running sweep 2 of 20
# Running sweep 3 of 20
# Running sweep 4 of 20
# Running sweep 5 of 20
# Running sweep 6 of 20
# Running sweep 7 of 20
# Running sweep 8 of 20
# Running sweep 9 of 20
# Running sweep 10 of 20
# Running sweep 11 of 20
# Running sweep 12 of 20
# Running sweep 13 of 20
# Running sweep 14 of 20
# Running sweep 15 of 20
# Running sweep 16 of 20
# Running sweep 17 of 20
# Running sweep 18 of 20
# Running sweep 19 of 20
# Running sweep 20 of 20

# %%
for i in range(len(history.nameToSeries['w'])):
    plot([v[0] for v in history.nameToSeries['w'][i].values])
    plot([v[1] for v in history.nameToSeries['w'][i].values])
