# %% [markdown]
# # MRF with Binary Variables

# %%
from venture.venturemagics.ip_parallel import *
import ipdb
make_ripl = make_lite_church_prime_ripl

# %%
v=make_ripl()

# %% [markdown]
# ## Potential of two variables

# %%
D = 3
psi = np.exp(np.random.normal(0, np.sqrt(0.02), D * (D-1) / 2 * 2**2))

# %%
v.clear()
for d in range(D):
    v.assume('x_%d' % d, '(scope_include (quote global_var) %d (bernoulli 0.5))' % d)

n = 0
for d1 in range(D):
    str_x1 = 'x_%d' % d1
    for d2 in range(d1+1, D):
        str_x2 = 'x_%d' % d2
        
        # Potential with (X1, X2)
        str_y = '(bernoulli (+'
        for x1 in [True, False]:
            for x2 in [True, False]:
                # Value of (X1=x1, X2=x2)
                str_y += ' (* %f (and %s %s))' % (psi[n],
                                                  str_x1 if x1 else '(not %s)' % str_x1, 
                                                  str_x2 if x2 else '(not %s)' % str_x2)
                n += 1
        str_y += '))'
        print '[assume y_%d_%d' % (d1,d2), str_y, ']'
        v.assume('y_%d_%d' % (d1,d2), str_y)
        v.observe('y_%d_%d' % (d1,d2), True)
# Out:
# [assume y_0_1 (bernoulli (+ (* 1.098810 (and x_0 x_1)) (* 1.245340 (and x_0 (not x_1))) (* 0.926158 (and (not x_0) x_1)) (* 0.719838 (and (not x_0) (not x_1))))) ]
# [assume y_0_2
#  (bernoulli (+ (* 1.084581 (and x_0 x_2)) (* 1.029119 (and x_0 (not x_2))) (* 1.182525 (and (not x_0) x_2)) (* 1.067653 (and (not x_0) (not x_2))))) ]
# [assume y_1_2
#  (bernoulli (+ (* 1.002101 (and x_1 x_2)) (* 1.123923 (and x_1 (not x_2))) (* 1.227074 (and (not x_1) x_2)) (* 0.967852 (and (not x_1) (not x_2))))) ]

# %%
plt.figure(figsize=(30,30))
v.infer({'kernel': 'draw_scaffold', 'scope': 'global_var', 'block' : 'all', 'transitions': 1})

# %% [markdown]
# ## Potential of three variables

# %%
D = 4
psi = np.exp(np.random.normal(0, np.sqrt(0.02), D * (D-1) * (D-2) / 6 * 2**3))

# %%
v.clear()
for d in range(D):
    v.assume('x_%d' % d, '(scope_include (quote global_var) %d (bernoulli 0.5))' % d)

n = 0
for d1 in range(D):
    str_x1 = 'x_%d' % d1
    for d2 in range(d1+1, D):
        str_x2 = 'x_%d' % d2
        for d3 in range(d2+1, D):
            str_x3 = 'x_%d' % d3
            
            # Potential with (X1, X2, X3)
            str_y = '(bernoulli (+'
            for x1 in [True, False]:
                for x2 in [True, False]:
                    for x3 in [True, False]:
                        # Value of (X1=x1, X2=x2, X3=x3)
                        str_y += ' (* %f (and %s (and %s %s)))' % (psi[n],
                                                                   str_x1 if x1 else '(not %s)' % str_x1, 
                                                                   str_x2 if x2 else '(not %s)' % str_x2,
                                                                   str_x3 if x3 else '(not %s)' % str_x3)
                        n += 1
            str_y += '))'
            v.assume('y_%d_%d_%d' % (d1,d2,d3), str_y)
            v.observe('y_%d_%d_%d' % (d1,d2,d3), True)

# %%
plt.figure(figsize=(40,40))
v.infer({'kernel': 'draw_scaffold', 'scope': 'global_var', 'block' : 0, 'transitions': 1})
